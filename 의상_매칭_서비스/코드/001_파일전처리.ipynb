# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# ### 파일 전처리
# ### 하나의 열에 name, type 값이 같이 들어있어서 나눠주고, 새로운 csv 파일로 저장

# %%
# 원본 파일 열어보면 맨 위에 나온 숫자 = 행의 갯수
# 직접 지워서 사용함


# 1. list_attr_cloth 파일 

df_1 = pd.read_csv('E:\Project\list_attr_cloth.txt')
display(df_1)

df_1.columns #['attribute_name  attribute_type']
df_1['attribute_name'] = df_1['attribute_name  attribute_type'].str[:-1]
df_1['attribute_type'] = df_1['attribute_name  attribute_type'].str[-1]
display(df_1)
df_1.to_csv('E:\Project\list_attr_cloth.csv', header=True, index=False)


# 2. list_attr_img


# 3. list_category_cloth


# 4. list_category_img

df_2 = pd.read_csv('E:\Project\list_category_img.txt', encoding='UTF-8')
display(df_2)
# Out:
#      attribute_name  attribute_type
# 0    a-line                       3
# 1    abstract                     1
# 2    abstract chevron             1
# 3    abstract chevron print       1
# 4    abstract diamond             1
# ..                              ...
# 995  zip-pocket                   4
# 996  zip-up                       4
# 997  zipped                       4
# 998  zipper                       4
# 999  zippered                     4
#
# [1000 rows x 1 columns]
#      attribute_name  attribute_type                 attribute_name  \
# 0    a-line                       3  a-line
# 1    abstract                     1  abstract
# 2    abstract chevron             1  abstract chevron
# 3    abstract chevron print       1  abstract chevron print
# 4    abstract diamond             1  abstract diamond
# ..                              ...                            ...
# 995  zip-pocket                   4  zip-pocket
# 996  zip-up                       4  zip-up
# 997  zipped                       4  zipped
# 998  zipper                       4  zipper
# 999  zippered                     4  zippered
#
#     attribute_type
# 0                3
# 1                1
# 2                1
# 3                1
# 4                1
# ..             ...
# 995              4
# 996              4
# 997              4
# 998              4
# 999              4
#
# [1000 rows x 3 columns]
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-53-4d7edb902a1b> in <module>
#      23 # 4. list_category_img
#      24
# ---> 25 df_2 = pd.read_csv('E:\Project\list_category_img.txt', encoding='UTF-8')
#      26 display(df_2)
#
# ~\Anaconda3\envs\cpu_env\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\Anaconda3\envs\cpu_env\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# ~\Anaconda3\envs\cpu_env\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~\Anaconda3\envs\cpu_env\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 47206, saw 2
