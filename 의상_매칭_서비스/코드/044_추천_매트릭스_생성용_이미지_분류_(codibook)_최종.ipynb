# %%
import requests
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.pyplot import imshow
import numpy as np
import pandas as pd
import sys
from PIL import Image, ImageDraw, ImageFont
import json
import cv2
import os
import time
import tensorflow as tf
from keras import layers, Input, models, optimizers
from keras.models import Model, Sequential
from keras.models import load_model
from keras import layers, Input, models, optimizers
from keras.layers import MaxPooling2D, Conv2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.callbacks import ModelCheckpoint
from keras.layers.normalization import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.applications import VGG16

# %%
# 이전까지 만든 분류 모델 사용할 것
# 새로 crawling 이미지를 가지고 모델을 통해 추천값 matrix 짜기 위한 dataframe 출력
# 동시에 각자 의류 종류, 패턴에 따라 폴더 생성하고 해당되는 이미지 저장 : 나중에 추천시 가져올 수 있게

# %%
# 폴더 생성 함수

def createfolder(foler_dir):
    try:
        if not os.path.exists(folder_dir):
            os.makedirs(folder_dir)
    except OSError:
        print('Error Creating directory'+folder_dir)

# %%
# 자른 이미지 저장할 폴더 생성

shape_list = ['Hoodie', 'Long-sleeve-tee', 'Shirts', 'Short-sleeve-tee', 'Sweater', 
             'Chiffon-skirt', 'Cotten-long-pants', 'Cutoffs', 'H-line-skirt', 'Jeans']
pattern_list = ['Check', 'Dot', 'Floral', 'Graphic', 'Leopard', 'None', 'Stripe']

for shape in shape_list:
    for pattern in pattern_list:
        folder_name = str(shape +'_'+ pattern)
        folder_dir = str('./img/cropped/' + folder_name)
        createfolder(folder_dir)

# %%
# 원피스 사진도 혹시 모르니 저장하는 폴더 생성

pattern_list = ['Check', 'Dot', 'Floral', 'Graphic', 'Leopard', 'None', 'Stripe']

for pattern in pattern_list:
    folder_name = str('One-piece' + '_' + pattern)
    folder_dir = str('./img/cropped/' + folder_name)
    createfolder(folder_dir)

# %% [markdown]
# ## 이거는 사전 훈련된 pattern, shape 모델로 예측시 사용

# %%
# 전신 이미지 가져와서 상하의 원피스 shape, pattern, style 출력 및 각각 사진 잘라서 저장

def style_shape_pattern(img_dir,                                                      # 이미지 가져오는 주소
                        model_pattern, var_pattern, 
                        model_top, var_top, model_bottom, var_bottom, 
                        model_style, var_style,
                        file_name):                                                    # 이미지 잘라서 저장할 떄 사용할 이름 
    
    # VGG 다운
    conv_base = VGG16(weights = 'imagenet',include_top=False,input_shape=(150,150,3))
    
    # top shape model 안잡혀서 한번 더 잡아주고 weight로 로드함
    top_model = models.Sequential()
    top_model.add(layers.Dense(256, activation='relu', input_dim = 4 * 4 * 512))
    top_model.add(layers.Dropout(0.5))
    top_model.add(layers.Dense(4, activation='softmax'))
    top_model.compile(optimizer = optimizers.RMSprop(lr=2e-5),
                      loss='categorical_crossentropy',
                      metrics=['acc'])
    top_model.load_weights(model_top)
    
    # pattern model 안잡혀서 한번 더 잡아주고 weight로 로드함
    pattern_model = models.Sequential()
    pattern_model.add(layers.Dense(256, activation='relu', input_dim = 4 * 4 * 512))
    pattern_model.add(layers.Dropout(0.5))
    pattern_model.add(layers.Dense(7, activation='softmax'))
    pattern_model.compile(optimizer = optimizers.RMSprop(lr=2e-5),
                      loss='categorical_crossentropy',
                      metrics=['acc'])
    pattern_model.load_weights(model_pattern)
    
    # 사용할 model 설정
    bottom_model = load_model(model_bottom)
    style_model = load_model(model_style)
    
    # 카카오 API 설정
    API_URL = 'https://kapi.kakao.com/v1/vision/product/detect'
    MYAPP_KEY = 'd18d428d5309f101d99cebdf4bc87b3e'                        #'d7f9bbf32defc3826369883e77412c40'
    url = "https://kapi.kakao.com/v1/vision/product/detect"       
    headers = {'Authorization': 'KakaoAK {}'.format(MYAPP_KEY)}
    files = { 'file' : open(img_dir, 'rb')}
    response = requests.post(url, headers=headers, files=files)
    
    # 카카오 API 저장 및 예외 상황 설정
    info = []
    result = response.json()
    
    if 'result' in result:                                                    
        fig_w, fig_h = result['result']['width'], result['result']['height']
    else:
        return ['NA','NA','NA','NA','NA','NA','NA']

    if 'objects' in result['result']:
        mylist = result['result']['objects']
        cnt = 0
        for objects in mylist:
            if objects['class'] in ['shirts','blouse','t-shirts','pants','outer','skirt','one-piece']:
                cnt = cnt+1
        if cnt > 4:
            return ['NA','NA','NA','NA','NA','NA','NA']
    else:
        return ['NA','NA','NA','NA','NA','NA','NA']
        
    for each in result['result']['objects']:                        
            each = list(each.values())                                            
            info.append(each)
            
    
    # 사진 상하의 구분 및 pattern, shape 예측
    top_pattern = []
    top_shape = []
    bottom_pattern = []
    bottom_shape = []
    one = []
    one_pattern = []
    outer = []
    
    # 사진 전체의 style 예측 
    img = Image.open(img_dir)
    img = img.resize((150,150))
    data = np.array(img)
    data = data.astype('float')
    data = data/255
    data = data.reshape((1,150,150,3))
    st = var_style[style_model.predict_classes(data)[0]]
    style = [st]

    
    # 상의 조금 더 타이트하게 구분하기 위한 crop 값 설정
    upper = list()
    lower = list()
    for _ in result['result']['objects']:
        if _['class'] in ('t-shirts', 'shirts','blouse','sweater'):
            upper = _
        elif _['class'] in ('skirt', 'pants'):
            lower = _
    
    if len(upper) != 0 and len(lower) != 0:

        x1 = lower['x1']*fig_w -5   
        y1 = lower['y1']*fig_h -5    
        w1 = lower['x2']*fig_w +5   
        h1 = lower['y2']*fig_h +5   

        x2 = upper['x1']*fig_w -5   
        y2 = upper['y1']*fig_h -5   
        w2 = upper['x2']*fig_w +5   
        h2 = y1
    
    # 예측 및 저장하기
    for _ in range(len(info)):
        img = Image.open(img_dir)
        category = info[_][4]

        if category in ('shirts','t-shirts','blouse','sweater'):
            if len(top_pattern) == 1 or len(top_shape) == 1:
                pass
            else:
                x = info[_][0]*fig_w - 5
                y = info[_][1]*fig_h - 5
                w = info[_][2]*fig_w + 5
                h = info[_][3]*fig_h + 5   
                cropped_top = img.crop((x,y,w,h))           # 저장용
                
                if len(upper) != 0 and len(lower) !=0:
                    img = Image.open(img_dir)
                    img = img.crop((x2,y2,w2,h2))       # 예측용   
                else:
                    img = cropped_top
                img.show()
                cropped_top.show()
                
                img = img.resize((150,150))
                data = np.array(img)
                data = data.astype('float')
                data = data/255
                data = data.reshape((1,150,150,3))  

                # top pattern 예측
                p = conv_base.predict(data)
                p = p.reshape((-1,8192))
                p = pattern_model.predict_classes(p)[0]
                p = var_pattern[p]
                top_pattern.append(p)

                # top shape 예측
                s = conv_base.predict(data)
                s = s.reshape((-1,8192))
                s = top_model.predict_classes(s)[0]
                s = var_top[s]
                top_shape.append(s)  

                #자른 사진 저장
                save_name = str(st + '_' + s + '_' + p + '_' + file_name )
                path = str('./img/cropped/' + s + '_' + p + '/')
                cropped_top.save( path + save_name )

        
        elif category in ('pants','skirt'): 
            if len(bottom_pattern) == 1 or len(bottom_shape) == 1:
                pass
            else:            
                x = info[_][0]*fig_w - 5
                y = info[_][1]*fig_h - 5
                w = info[_][2]*fig_w + 5
                h = info[_][3]*fig_h + 5 
                img = img.crop((x,y,w,h))                               
                img.show()
                cropped_bottom = img
                
                img = img.resize((150,150))
                data = np.array(img)
                data = data.astype('float')
                data = data/255
                data = data.reshape((1,150,150,3))

                # bottom pattern 예측
                p = conv_base.predict(data)
                p = p.reshape((-1,8192))
                p = pattern_model.predict_classes(p)[0]
                p = var_pattern[p]
                bottom_pattern.append(p)

                # bottom shape 예측
                s = conv_base.predict(data)
                s = s.reshape((-1,8192))
                s = bottom_model.predict_classes(s)[0]
                s = var_bottom[s]
                bottom_shape.append(s) 

                # 자른 이미지 저장
                save_name = str(st + '_' + s + '_' + p + '_' + file_name )
                path = str('./img/cropped/' + s + '_' + p + '/')
                cropped_bottom.save( path + save_name )
                
        # 원피스        
        elif category in ('one-piece'):
            one.append('one-piece')
            
            if len(one_pattern) == 1 :
                pass
            else:
                x = info[_][0]*fig_w - 5
                y = info[_][1]*fig_h - 5
                w = info[_][2]*fig_w + 5
                h = info[_][3]*fig_h + 5
                img = img.crop((x,y,w,h))  
                cropped_one = img
                img.show()
                
                img = img.resize((150,150))
                data = np.array(img)
                data = data.astype('float')
                data = data/255
                data = data.reshape((1,150,150,3))  

                # one-piece pattern 예측
                p = conv_base.predict(data)
                p = p.reshape((-1,8192))
                p = pattern_model.predict_classes(p)[0]
                p = var_pattern[p]
                one_pattern.append(p)

                # 자른 이미지 저장 
                s = 'One-piece'
                save_name = str(st + '_' + s + '_' + p + '_' + file_name )
                path = str('./img/cropped/' + 'One-piece' + '_' + p + '/')
                cropped_one.save( path + save_name )  
                

    # 6)예측값이 없는 경우는 'NA' 값으로 표기
    if len(top_pattern) == 0:
        top_pattern = ['NA']
    if len(top_shape) == 0:
        top_shape = ['NA']        
    if len(bottom_pattern) == 0:
        bottom_pattern = ['NA']
    if len(bottom_shape) == 0:
        bottom_shape = ['NA']
    if len(style) == 0:
        style = ['NA']
    if len(one) == 0:
        one = ['NA']
    if len(one_pattern) == 0:
        one_pattern = ['NA']    


    return ( style + top_shape + top_pattern + bottom_shape + bottom_pattern + one + one_pattern  )

# %% [markdown]
# ## 하나 폴더 내 여러 이미지 불러와 자르고 분류 및 분류값 dataframe으로 출력

# %%
import datetime

# %%
def predict_multi(folder_dir,                                                     
                  model_pattern, var_pattern, 
                  model_top, var_top, model_bottom, var_bottom, 
                  model_style, var_style):
    
    file_list = os.listdir(folder_dir)
    df = pd.DataFrame(index=range(0,0), 
                      columns=['img_dir', 'style', 'top shape', 'top pattern', 'bottom shape', 'bottom pattern',
                               'one-piece','one-piece pattern'])
    display(df)
    
    for _ in range(len(file_list)):
        
        try:
        
            img_dir = str(folder_dir + '/' + file_list[_])
            Image.open(img_dir)

            file_name = file_list[_]
            k = style_shape_pattern(img_dir,                                                     
                                    model_pattern, var_pattern, 
                                    model_top, var_top, model_bottom, var_bottom, 
                                    model_style, var_style,
                                    file_name)   
        
        # file_name : crop 하기 전 전신 이미지 파일명
        
            total = [file_name] + k
            df.loc[_] = total
            display(df)
        except:
            print('error!!!!!!!!!!!!!!!!!!!')
            pass
        
        print(_, datetime.datetime.now())
            
    return df

# %% [markdown]
# ## 코드 실행하기 전에 확인!! : folder_dir, model 유무

# %%
model_pattern = './model/pattern_9985.h5'
var_pattern =  ['Check', 'Dot', 'Floral', 'Graphic', 'Leopard', 'None', 'Stripe']

model_top = './model/upper_9978.h5'
var_top = ['Hoodie', 'Long-sleeve-tee', 'Shirts', 'Short-sleeve-tee', 'Sweater',]

model_bottom = './model/lower0425_9990.h5'
var_bottom = ['Chiffon-skirt', 'Cotten-long-pants', 'Cutoffs', 'H-line-skirt', 'Jeans']

model_style = './model/style_model_1_90,63.h5'
var_style =  ['Casual', 'Feminine', 'Formal']

folder_dir = './img/matrix/codibook_1000'

# %%
df = predict_multi(folder_dir,
                   model_pattern, var_pattern,
                   model_top, var_top, model_bottom, var_bottom,
                   model_style, var_style)
# Out:
# Empty DataFrame
# Columns: [img_dir, style, top shape, top pattern, bottom shape, bottom pattern, one-piece, one-piece pattern]
# Index: []
#                img_dir   style        top shape top pattern  bottom shape  \
# 0  codibook (1000).jpg  Formal  Long-sleeve-tee        None  H-line-skirt
#
#   bottom pattern one-piece one-piece pattern
# 0           None        NA                NA
# 0 2020-04-28 10:05:05.617057
#                img_dir   style        top shape top pattern  \
# 0  codibook (1000).jpg  Formal  Long-sleeve-tee        None
# 1   codibook (801).jpg  Formal           Hoodie        None
#
#         bottom shape bottom pattern one-piece one-piece pattern
# 0       H-line-skirt           None        NA                NA
# 1  Cotten-long-pants           None        NA                NA
# 1 2020-04-28 10:05:14.643584
#                img_dir   style        top shape top pattern  \
# 0  codibook (1000).jpg  Formal  Long-sleeve-tee        None
# 1   codibook (801).jpg  Formal           Hoodie        None
# 2   codibook (802).jpg  Formal           Shirts     Graphic
#
#         bottom shape bottom pattern one-piece one-piece pattern
# 0       H-line-skirt           None        NA                NA
# 1  Cotten-long-pants           None        NA                NA
# 2            Cutoffs           None        NA                NA
# 2 2020-04-28 10:05:24.958440
#                img_dir   style        top shape top pattern  \
# 0  codibook (1000).jpg  Formal  Long-sleeve-tee        None
# 1   codibook (801).jpg  Formal           Hoodie        None
# 2   codibook (802).jpg  Formal           Shirts     Graphic
# 3   codibook (803).jpg  Formal           Shirts       Check
#
#         bottom shape bottom pattern one-piece one-piece pattern
# 0       H-line-skirt           None        NA                NA
# 1  Cotten-long-pants           None        NA                NA
# 2            Cutoffs           None        NA                NA
# 3              Jeans           None        NA                NA
# 3 2020-04-28 10:05:36.692372
#                img_dir   style        top shape top pattern  \
# 0  codibook (1000).jpg  Formal  Long-sleeve-tee        None
# 1   codibook (801).jpg  Formal           Hoodie        None
# 2   codibook (802).jpg  Formal           Shirts     Graphic
# 3   codibook (803).jpg  Formal           Shirts       Check
# 4   codibook (804).jpg  Casual  Long-sleeve-tee     Graphic
#
#         bottom shape bottom pattern one-piece one-piece pattern
# 0       H-line-skirt           None        NA                NA
# 1  Cotten-long-pants           None        NA                NA
# 2            Cutoffs           None        NA                NA
# 3              Jeans           None        NA                NA
# 4              Jeans           None        NA                NA
# 4 2020-04-28 10:05:49.530113
#                img_dir   style        top shape top pattern  \
# 0  codibook (1000).jpg  Formal  Long-sleeve-tee        None
# 1   codibook (801).jpg  Formal           Hoodie        None
# 2   codibook (802).jpg  Formal           Shirts     Graphic
# 3   codibook (803).jpg  Formal           Shirts       Check
# 4   codibook (804).jpg  Casual  Long-sleeve-tee     Graphic
# 5   codibook (805).jpg  Casual           Shirts       Check
#
#         bottom shape bottom pattern one-piece one-piece pattern
# 0       H-line-skirt           None        NA                NA
# 1  Cotten-long-pants           None        NA                NA
# 2            Cutoffs           None        NA                NA
# 3              Jeans           None        NA                NA
# 4              Jeans           None        NA                NA
# 5  Cotten-long-pants           None        NA                NA
# 5 2020-04-28 10:06:04.062772
#                img_dir   style        top shape top pattern  \
# 0  codibook (1000).jpg  Formal  Long-sleeve-tee        None
# 1   codibook (801).jpg  Formal           Hoodie        None
# 2   codibook (802).jpg  Formal           Shirts     Graphic
# 3   codibook (803).jpg  Formal           Shirts       Check
# 4   codibook (804).jpg  Casual  Long-sleeve-tee     Graphic
# 5   codibook (805).jpg  Casual           Shirts       Check
# 6   codibook (806).jpg  Formal  Long-sleeve-tee        None
#
#         bottom shape bottom pattern one-piece one-piece pattern
# 0       H-line-skirt           None        NA                NA
# 1  Cotten-long-pants           None        NA                NA
# 2            Cutoffs           None        NA                NA
# 3              Jeans           None        NA                NA
# 4              Jeans           None        NA                NA
# 5  Cotten-long-pants           None        NA                NA
# 6       H-line-skirt          Check        NA                NA
# 6 2020-04-28 10:06:20.095438
#                img_dir   style        top shape top pattern  \
# 0  codibook (1000).jpg  Formal  Long-sleeve-tee        None
# 1   codibook (801).jpg  Formal           Hoodie        None
# 2   codibook (802).jpg  Formal           Shirts     Graphic
# 3   codibook (803).jpg  Formal           Shirts       Check
# 4   codibook (804).jpg  Casual  Long-sleeve-tee     Graphic
# 5   codibook (805).jpg  Casual           Shirts       Check
# 6   codibook (806).jpg  Formal  Long-sleeve-tee        None
# 7   codibook (807).jpg  Casual  Long-sleeve-tee      Stripe
#
#         bottom shape bottom pattern one-piece one-piece pattern
# 0       H-line-skirt           None        NA                NA
# 1  Cotten-long-pants           None        NA                NA
# 2            Cutoffs           None        NA                NA
# 3              Jeans           None        NA                NA
# 4              Jeans           None        NA                NA
# 5  Cotten-long-pants           None        NA                NA
# 6       H-line-skirt          Check        NA                NA
# 7  Cotten-long-pants           None        NA                NA
# 7 2020-04-28 10:06:37.399439
#                img_dir   style        top shape top pattern  \
# 0  codibook (1000).jpg  Formal  Long-sleeve-tee        None
# 1   codibook (801).jpg  Formal           Hoodie        None
# 2   codibook (802).jpg  Formal           Shirts     Graphic
# 3   codibook (803).jpg  Formal           Shirts       Check
# 4   codibook (804).jpg  Casual  Long-sleeve-tee     Graphic
# 5   codibook (805).jpg  Casual           Shirts       Check
# 6   codibook (806).jpg  Formal  Long-sleeve-tee        None
# 7   codibook (807).jpg  Casual  Long-sleeve-tee      Stripe
# 8   codibook (808).jpg  Casual  Long-sleeve-tee     Graphic
#
#         bottom shape bottom pattern one-piece one-piece pattern
# 0       H-line-skirt           None        NA                NA
# 1  Cotten-long-pants           None        NA                NA
# 2            Cutoffs           None        NA                NA
# 3              Jeans           None        NA                NA
# 4              Jeans           None        NA                NA
# 5  Cotten-long-pants           None        NA                NA
# 6       H-line-skirt          Check        NA                NA
# 7  Cotten-long-pants           None        NA                NA
# 8      Chiffon-skirt           None        NA                NA
# 8 2020-04-28 10:06:56.285576
#                img_dir   style        top shape top pattern  \
# 0  codibook (1000).jpg  Formal  Long-sleeve-tee        None
# 1   codibook (801).jpg  Formal           Hoodie        None
# 2   codibook (802).jpg  Formal           Shirts     Graphic
# 3   codibook (803).jpg  Formal           Shirts       Check
# 4   codibook (804).jpg  Casual  Long-sleeve-tee     Graphic
# 5   codibook (805).jpg  Casual           Shirts       Check
# 6   codibook (806).jpg  Formal  Long-sleeve-tee        None
# 7   codibook (807).jpg  Casual  Long-sleeve-tee      Stripe
# 8   codibook (808).jpg  Casual  Long-sleeve-tee     Graphic
# 9   codibook (809).jpg  Casual  Long-sleeve-tee        None
#
#         bottom shape bottom pattern one-piece one-piece pattern
# 0       H-line-skirt           None        NA                NA
# 1  Cotten-long-pants           None        NA                NA
# 2            Cutoffs           None        NA                NA
# 3              Jeans           None        NA                NA
# 4              Jeans           None        NA                NA
# 5  Cotten-long-pants           None        NA                NA
# 6       H-line-skirt          Check        NA                NA
# 7  Cotten-long-pants           None        NA                NA
# 8      Chiffon-skirt           None        NA                NA
# 9  Cotten-long-pants           None        NA                NA
# 9 2020-04-28 10:07:16.756697
#                 img_dir   style        top shape top pattern  \
# 0   codibook (1000).jpg  Formal  Long-sleeve-tee        None
# 1    codibook (801).jpg  Formal           Hoodie        None
# 2    codibook (802).jpg  Formal           Shirts     Graphic
# 3    codibook (803).jpg  Formal           Shirts       Check
# 4    codibook (804).jpg  Casual  Long-sleeve-tee     Graphic
# 5    codibook (805).jpg  Casual           Shirts       Check
# 6    codibook (806).jpg  Formal  Long-sleeve-tee        None
# 7    codibook (807).jpg  Casual  Long-sleeve-tee      Stripe
# 8    codibook (808).jpg  Casual  Long-sleeve-tee     Graphic
# 9    codibook (809).jpg  Casual  Long-sleeve-tee        None
# 10   codibook (810).jpg  Formal           Shirts       Check
#
#          bottom shape bottom pattern one-piece one-piece pattern
# 0        H-line-skirt           None        NA                NA
# 1   Cotten-long-pants           None        NA                NA
# 2             Cutoffs           None        NA                NA
# 3               Jeans           None        NA                NA
# 4               Jeans           None        NA                NA
# 5   Cotten-long-pants           None        NA                NA
# 6        H-line-skirt          Check        NA                NA
# 7   Cotten-long-pants           None        NA                NA
# 8       Chiffon-skirt           None        NA                NA
# 9   Cotten-long-pants           None        NA                NA
# 10  Cotten-long-pants           None        NA                NA
# 10 2020-04-28 10:07:38.731256
#                 img_dir   style        top shape top pattern  \
# 0   codibook (1000).jpg  Formal  Long-sleeve-tee        None
# 1    codibook (801).jpg  Formal           Hoodie        None
# 2    codibook (802).jpg  Formal           Shirts     Graphic
# 3    codibook (803).jpg  Formal           Shirts       Check
# 4    codibook (804).jpg  Casual  Long-sleeve-tee     Graphic
# 5    codibook (805).jpg  Casual           Shirts       Check
# 6    codibook (806).jpg  Formal  Long-sleeve-tee        None
# 7    codibook (807).jpg  Casual  Long-sleeve-tee      Stripe
# 8    codibook (808).jpg  Casual  Long-sleeve-tee     Graphic
# 9    codibook (809).jpg  Casual  Long-sleeve-tee        None
# 10   codibook (810).jpg  Formal           Shirts       Check
# 11   codibook (811).jpg  Casual           Shirts        None
#
#          bottom shape bottom pattern one-piece one-piece pattern
# 0        H-line-skirt           None        NA                NA
# 1   Cotten-long-pants           None        NA                NA
# 2             Cutoffs           None        NA                NA
# 3               Jeans           None        NA                NA
# 4               Jeans           None        NA                NA
# 5   Cotten-long-pants           None        NA                NA
# 6        H-line-skirt          Check        NA                NA
# 7   Cotten-long-pants           None        NA                NA
# 8       Chiffon-skirt           None        NA                NA
# 9   Cotten-long-pants           None        NA                NA
# 10  Cotten-long-pants           None        NA                NA
# 11              Jeans           None        NA                NA
# 11 2020-04-28 10:08:02.083269
#                 img_dir   style         top shape top pattern  \
# 0   codibook (1000).jpg  Formal   Long-sleeve-tee        None
# 1    codibook (801).jpg  Formal            Hoodie        None
# 2    codibook (802).jpg  Formal            Shirts     Graphic
# 3    codibook (803).jpg  Formal            Shirts       Check
# 4    codibook (804).jpg  Casual   Long-sleeve-tee     Graphic
# 5    codibook (805).jpg  Casual            Shirts       Check
# 6    codibook (806).jpg  Formal   Long-sleeve-tee        None
# 7    codibook (807).jpg  Casual   Long-sleeve-tee      Stripe
# 8    codibook (808).jpg  Casual   Long-sleeve-tee     Graphic
# 9    codibook (809).jpg  Casual   Long-sleeve-tee        None
# 10   codibook (810).jpg  Formal            Shirts       Check
# 11   codibook (811).jpg  Casual            Shirts        None
# 12   codibook (812).jpg  Formal  Short-sleeve-tee     Graphic
#
#          bottom shape bottom pattern one-piece one-piece pattern
# 0        H-line-skirt           None        NA                NA
# 1   Cotten-long-pants           None        NA                NA
# 2             Cutoffs           None        NA                NA
# 3               Jeans           None        NA                NA
# 4               Jeans           None        NA                NA
# 5   Cotten-long-pants           None        NA                NA
# 6        H-line-skirt          Check        NA                NA
# 7   Cotten-long-pants           None        NA                NA
# 8       Chiffon-skirt           None        NA                NA
# 9   Cotten-long-pants           None        NA                NA
# 10  Cotten-long-pants           None        NA                NA
# 11              Jeans           None        NA                NA
# 12  Cotten-long-pants           None        NA                NA
# 12 2020-04-28 10:08:27.423867
#                 img_dir   style         top shape top pattern  \
# 0   codibook (1000).jpg  Formal   Long-sleeve-tee        None
# 1    codibook (801).jpg  Formal            Hoodie        None
# 2    codibook (802).jpg  Formal            Shirts     Graphic
# 3    codibook (803).jpg  Formal            Shirts       Check
# 4    codibook (804).jpg  Casual   Long-sleeve-tee     Graphic
# 5    codibook (805).jpg  Casual            Shirts       Check
# 6    codibook (806).jpg  Formal   Long-sleeve-tee        None
# 7    codibook (807).jpg  Casual   Long-sleeve-tee      Stripe
# 8    codibook (808).jpg  Casual   Long-sleeve-tee     Graphic
# 9    codibook (809).jpg  Casual   Long-sleeve-tee        None
# 10   codibook (810).jpg  Formal            Shirts       Check
# 11   codibook (811).jpg  Casual            Shirts        None
# 12   codibook (812).jpg  Formal  Short-sleeve-tee     Graphic
# 13   codibook (813).jpg  Casual                NA          NA
#
#          bottom shape bottom pattern one-piece one-piece pattern
# 0        H-line-skirt           None        NA                NA
# 1   Cotten-long-pants           None        NA                NA
# 2             Cutoffs           None        NA                NA
# 3               Jeans           None        NA                NA
# 4               Jeans           None        NA                NA
# 5   Cotten-long-pants           None        NA                NA
# 6        H-line-skirt          Check        NA                NA
# 7   Cotten-long-pants           None        NA                NA
# 8       Chiffon-skirt           None        NA                NA
# 9   Cotten-long-pants           None        NA                NA
# 10  Cotten-long-pants           None        NA                NA
# 11              Jeans           None        NA                NA
# 12  Cotten-long-pants           None        NA                NA
# 13  Cotten-long-pants           None        NA                NA
# 13 2020-04-28 10:08:50.204610
#                 img_dir   style         top shape top pattern  \
# 0   codibook (1000).jpg  Formal   Long-sleeve-tee        None
# 1    codibook (801).jpg  Formal            Hoodie        None
# 2    codibook (802).jpg  Formal            Shirts     Graphic
# 3    codibook (803).jpg  Formal            Shirts       Check
# 4    codibook (804).jpg  Casual   Long-sleeve-tee     Graphic
# 5    codibook (805).jpg  Casual            Shirts       Check
# 6    codibook (806).jpg  Formal   Long-sleeve-tee        None
# 7    codibook (807).jpg  Casual   Long-sleeve-tee      Stripe
# 8    codibook (808).jpg  Casual   Long-sleeve-tee     Graphic
# 9    codibook (809).jpg  Casual   Long-sleeve-tee        None
# 10   codibook (810).jpg  Formal            Shirts       Check
# 11   codibook (811).jpg  Casual            Shirts        None
# 12   codibook (812).jpg  Formal  Short-sleeve-tee     Graphic
# 13   codibook (813).jpg  Casual                NA          NA
# 14   codibook (814).jpg  Formal                NA          NA
#
#          bottom shape bottom pattern one-piece one-piece pattern
# 0        H-line-skirt           None        NA                NA
# 1   Cotten-long-pants           None        NA                NA
# 2             Cutoffs           None        NA                NA
# 3               Jeans           None        NA                NA
# 4               Jeans           None        NA                NA
# 5   Cotten-long-pants           None        NA                NA
# 6        H-line-skirt          Check        NA                NA
# 7   Cotten-long-pants           None        NA                NA
# 8       Chiffon-skirt           None        NA                NA
# 9   Cotten-long-pants           None        NA                NA
# 10  Cotten-long-pants           None        NA                NA
# 11              Jeans           None        NA                NA
# 12  Cotten-long-pants           None        NA                NA
# 13  Cotten-long-pants           None        NA                NA
# 14            Cutoffs           None        NA                NA
# 14 2020-04-28 10:09:14.684039
#                 img_dir   style         top shape top pattern  \
# 0   codibook (1000).jpg  Formal   Long-sleeve-tee        None
# 1    codibook (801).jpg  Formal            Hoodie        None
# 2    codibook (802).jpg  Formal            Shirts     Graphic
# 3    codibook (803).jpg  Formal            Shirts       Check
# 4    codibook (804).jpg  Casual   Long-sleeve-tee     Graphic
# 5    codibook (805).jpg  Casual            Shirts       Check
# 6    codibook (806).jpg  Formal   Long-sleeve-tee        None
# 7    codibook (807).jpg  Casual   Long-sleeve-tee      Stripe
# 8    codibook (808).jpg  Casual   Long-sleeve-tee     Graphic
# 9    codibook (809).jpg  Casual   Long-sleeve-tee        None
# 10   codibook (810).jpg  Formal            Shirts       Check
# 11   codibook (811).jpg  Casual            Shirts        None
# 12   codibook (812).jpg  Formal  Short-sleeve-tee     Graphic
# 13   codibook (813).jpg  Casual                NA          NA
# 14   codibook (814).jpg  Formal                NA          NA
# 15   codibook (815).jpg  Casual                NA          NA
#
#          bottom shape bottom pattern one-piece one-piece pattern
# 0        H-line-skirt           None        NA                NA
# 1   Cotten-long-pants           None        NA                NA
# 2             Cutoffs           None        NA                NA
# 3               Jeans           None        NA                NA
# 4               Jeans           None        NA                NA
# 5   Cotten-long-pants           None        NA                NA
# 6        H-line-skirt          Check        NA                NA
# 7   Cotten-long-pants           None        NA                NA
# 8       Chiffon-skirt           None        NA                NA
# 9   Cotten-long-pants           None        NA                NA
# 10  Cotten-long-pants           None        NA                NA
# 11              Jeans           None        NA                NA
# 12  Cotten-long-pants           None        NA                NA
# 13  Cotten-long-pants           None        NA                NA
# 14            Cutoffs           None        NA                NA
# 15            Cutoffs          Check        NA                NA
# 15 2020-04-28 10:09:41.032560
#                 img_dir     style         top shape top pattern  \
# 0   codibook (1000).jpg    Formal   Long-sleeve-tee        None
# 1    codibook (801).jpg    Formal            Hoodie        None
# 2    codibook (802).jpg    Formal            Shirts     Graphic
# 3    codibook (803).jpg    Formal            Shirts       Check
# 4    codibook (804).jpg    Casual   Long-sleeve-tee     Graphic
# 5    codibook (805).jpg    Casual            Shirts       Check
# 6    codibook (806).jpg    Formal   Long-sleeve-tee        None
# 7    codibook (807).jpg    Casual   Long-sleeve-tee      Stripe
# 8    codibook (808).jpg    Casual   Long-sleeve-tee     Graphic
# 9    codibook (809).jpg    Casual   Long-sleeve-tee        None
# 10   codibook (810).jpg    Formal            Shirts       Check
# 11   codibook (811).jpg    Casual            Shirts        None
# 12   codibook (812).jpg    Formal  Short-sleeve-tee     Graphic
# 13   codibook (813).jpg    Casual                NA          NA
# 14   codibook (814).jpg    Formal                NA          NA
# 15   codibook (815).jpg    Casual                NA          NA
# 16   codibook (816).jpg  Feminine            Hoodie        None
#
#          bottom shape bottom pattern one-piece one-piece pattern
# 0        H-line-skirt           None        NA                NA
# 1   Cotten-long-pants           None        NA                NA
# 2             Cutoffs           None        NA                NA
# 3               Jeans           None        NA                NA
# 4               Jeans           None        NA                NA
# 5   Cotten-long-pants           None        NA                NA
# 6        H-line-skirt          Check        NA                NA
# 7   Cotten-long-pants           None        NA                NA
# 8       Chiffon-skirt           None        NA                NA
# 9   Cotten-long-pants           None        NA                NA
# 10  Cotten-long-pants           None        NA                NA
# 11              Jeans           None        NA                NA
# 12  Cotten-long-pants           None        NA                NA
# 13  Cotten-long-pants           None        NA                NA
# 14            Cutoffs           None        NA                NA
# 15            Cutoffs          Check        NA                NA
# 16            Cutoffs           None        NA                NA
# 16 2020-04-28 10:10:12.781164
#                 img_dir     style         top shape top pattern  \
# 0   codibook (1000).jpg    Formal   Long-sleeve-tee        None
# 1    codibook (801).jpg    Formal            Hoodie        None
# 2    codibook (802).jpg    Formal            Shirts     Graphic
# 3    codibook (803).jpg    Formal            Shirts       Check
# 4    codibook (804).jpg    Casual   Long-sleeve-tee     Graphic
# 5    codibook (805).jpg    Casual            Shirts       Check
# 6    codibook (806).jpg    Formal   Long-sleeve-tee        None
# 7    codibook (807).jpg    Casual   Long-sleeve-tee      Stripe
# 8    codibook (808).jpg    Casual   Long-sleeve-tee     Graphic
# 9    codibook (809).jpg    Casual   Long-sleeve-tee        None
# 10   codibook (810).jpg    Formal            Shirts       Check
# 11   codibook (811).jpg    Casual            Shirts        None
# 12   codibook (812).jpg    Formal  Short-sleeve-tee     Graphic
# 13   codibook (813).jpg    Casual                NA          NA
# 14   codibook (814).jpg    Formal                NA          NA
# 15   codibook (815).jpg    Casual                NA          NA
# 16   codibook (816).jpg  Feminine            Hoodie        None
# 17   codibook (817).jpg    Formal                NA          NA
#
#          bottom shape bottom pattern one-piece one-piece pattern
# 0        H-line-skirt           None        NA                NA
# 1   Cotten-long-pants           None        NA                NA
# 2             Cutoffs           None        NA                NA
# 3               Jeans           None        NA                NA
# 4               Jeans           None        NA                NA
# 5   Cotten-long-pants           None        NA                NA
# 6        H-line-skirt          Check        NA                NA
# 7   Cotten-long-pants           None        NA                NA
# 8       Chiffon-skirt           None        NA                NA
# 9   Cotten-long-pants           None        NA                NA
# 10  Cotten-long-pants           None        NA                NA
# 11              Jeans           None        NA                NA
# 12  Cotten-long-pants           None        NA                NA
# 13  Cotten-long-pants           None        NA                NA
# 14            Cutoffs           None        NA                NA
# 15            Cutoffs          Check        NA                NA
# 16            Cutoffs           None        NA                NA
# 17  Cotten-long-pants           None        NA                NA
# 17 2020-04-28 10:10:42.102318
#                 img_dir     style         top shape top pattern  \
# 0   codibook (1000).jpg    Formal   Long-sleeve-tee        None
# 1    codibook (801).jpg    Formal            Hoodie        None
# 2    codibook (802).jpg    Formal            Shirts     Graphic
# 3    codibook (803).jpg    Formal            Shirts       Check
# 4    codibook (804).jpg    Casual   Long-sleeve-tee     Graphic
# 5    codibook (805).jpg    Casual            Shirts       Check
# 6    codibook (806).jpg    Formal   Long-sleeve-tee        None
# 7    codibook (807).jpg    Casual   Long-sleeve-tee      Stripe
# 8    codibook (808).jpg    Casual   Long-sleeve-tee     Graphic
# 9    codibook (809).jpg    Casual   Long-sleeve-tee        None
# 10   codibook (810).jpg    Formal            Shirts       Check
# 11   codibook (811).jpg    Casual            Shirts        None
# 12   codibook (812).jpg    Formal  Short-sleeve-tee     Graphic
# 13   codibook (813).jpg    Casual                NA          NA
# 14   codibook (814).jpg    Formal                NA          NA
# 15   codibook (815).jpg    Casual                NA          NA
# 16   codibook (816).jpg  Feminine            Hoodie        None
# 17   codibook (817).jpg    Formal                NA          NA
# 18   codibook (818).jpg    Casual            Shirts      Stripe
#
#          bottom shape bottom pattern one-piece one-piece pattern
# 0        H-line-skirt           None        NA                NA
# 1   Cotten-long-pants           None        NA                NA
# 2             Cutoffs           None        NA                NA
# 3               Jeans           None        NA                NA
# 4               Jeans           None        NA                NA
# 5   Cotten-long-pants           None        NA                NA
# 6        H-line-skirt          Check        NA                NA
# 7   Cotten-long-pants           None        NA                NA
# 8       Chiffon-skirt           None        NA                NA
# 9   Cotten-long-pants           None        NA                NA
# 10  Cotten-long-pants           None        NA                NA
# 11              Jeans           None        NA                NA
# 12  Cotten-long-pants           None        NA                NA
# 13  Cotten-long-pants           None        NA                NA
# 14            Cutoffs           None        NA                NA
# 15            Cutoffs          Check        NA                NA
# 16            Cutoffs           None        NA                NA
# 17  Cotten-long-pants           None        NA                NA
# 18            Cutoffs           None        NA                NA
# 18 2020-04-28 10:11:17.641705
#                 img_dir     style         top shape top pattern  \
# 0   codibook (1000).jpg    Formal   Long-sleeve-tee        None
# 1    codibook (801).jpg    Formal            Hoodie        None
# 2    codibook (802).jpg    Formal            Shirts     Graphic
# 3    codibook (803).jpg    Formal            Shirts       Check
# 4    codibook (804).jpg    Casual   Long-sleeve-tee     Graphic
# 5    codibook (805).jpg    Casual            Shirts       Check
# 6    codibook (806).jpg    Formal   Long-sleeve-tee        None
# 7    codibook (807).jpg    Casual   Long-sleeve-tee      Stripe
# 8    codibook (808).jpg    Casual   Long-sleeve-tee     Graphic
# 9    codibook (809).jpg    Casual   Long-sleeve-tee        None
# 10   codibook (810).jpg    Formal            Shirts       Check
# 11   codibook (811).jpg    Casual            Shirts        None
# 12   codibook (812).jpg    Formal  Short-sleeve-tee     Graphic
# 13   codibook (813).jpg    Casual                NA          NA
# 14   codibook (814).jpg    Formal                NA          NA
# 15   codibook (815).jpg    Casual                NA          NA
# 16   codibook (816).jpg  Feminine            Hoodie        None
# 17   codibook (817).jpg    Formal                NA          NA
# 18   codibook (818).jpg    Casual            Shirts      Stripe
# 19   codibook (819).jpg    Formal  Short-sleeve-tee        None
#
#          bottom shape bottom pattern one-piece one-piece pattern
# 0        H-line-skirt           None        NA                NA
# 1   Cotten-long-pants           None        NA                NA
# 2             Cutoffs           None        NA                NA
# 3               Jeans           None        NA                NA
# 4               Jeans           None        NA                NA
# 5   Cotten-long-pants           None        NA                NA
# 6        H-line-skirt          Check        NA                NA
# 7   Cotten-long-pants           None        NA                NA
# 8       Chiffon-skirt           None        NA                NA
# 9   Cotten-long-pants           None        NA                NA
# 10  Cotten-long-pants           None        NA                NA
# 11              Jeans           None        NA                NA
# 12  Cotten-long-pants           None        NA                NA
# 13  Cotten-long-pants           None        NA                NA
# 14            Cutoffs           None        NA                NA
# 15            Cutoffs          Check        NA                NA
# 16            Cutoffs           None        NA                NA
# 17  Cotten-long-pants           None        NA                NA
# 18            Cutoffs           None        NA                NA
# 19  Cotten-long-pants           None        NA                NA
# 19 2020-04-28 10:12:01.461300
#                 img_dir     style         top shape top pattern  \
# 0   codibook (1000).jpg    Formal   Long-sleeve-tee        None
# 1    codibook (801).jpg    Formal            Hoodie        None
# 2    codibook (802).jpg    Formal            Shirts     Graphic
# 3    codibook (803).jpg    Formal            Shirts       Check
# 4    codibook (804).jpg    Casual   Long-sleeve-tee     Graphic
# 5    codibook (805).jpg    Casual            Shirts       Check
# 6    codibook (806).jpg    Formal   Long-sleeve-tee        None
# 7    codibook (807).jpg    Casual   Long-sleeve-tee      Stripe
# 8    codibook (808).jpg    Casual   Long-sleeve-tee     Graphic
# 9    codibook (809).jpg    Casual   Long-sleeve-tee        None
# 10   codibook (810).jpg    Formal            Shirts       Check
# 11   codibook (811).jpg    Casual            Shirts        None
# 12   codibook (812).jpg    Formal  Short-sleeve-tee     Graphic
# 13   codibook (813).jpg    Casual                NA          NA
# 14   codibook (814).jpg    Formal                NA          NA
# 15   codibook (815).jpg    Casual                NA          NA
# 16   codibook (816).jpg  Feminine            Hoodie        None
# 17   codibook (817).jpg    Formal                NA          NA
# 18   codibook (818).jpg    Casual            Shirts      Stripe
# 19   codibook (819).jpg    Formal  Short-sleeve-tee        None
# 20   codibook (821).jpg  Feminine                NA          NA
#
#          bottom shape bottom pattern one-piece one-piece pattern
# 0        H-line-skirt           None        NA                NA
# 1   Cotten-long-pants           None        NA                NA
# 2             Cutoffs           None        NA                NA
# 3               Jeans           None        NA                NA
# 4               Jeans           None        NA                NA
# 5   Cotten-long-pants           None        NA                NA
# 6        H-line-skirt          Check        NA                NA
# 7   Cotten-long-pants           None        NA                NA
# 8       Chiffon-skirt           None        NA                NA
# 9   Cotten-long-pants           None        NA                NA
# 10  Cotten-long-pants           None        NA                NA
# 11              Jeans           None        NA                NA
# 12  Cotten-long-pants           None        NA                NA
# 13  Cotten-long-pants           None        NA                NA
# 14            Cutoffs           None        NA                NA
# 15            Cutoffs          Check        NA                NA
# 16            Cutoffs           None        NA                NA
# 17  Cotten-long-pants           None        NA                NA
# 18            Cutoffs           None        NA                NA
# 19  Cotten-long-pants           None        NA                NA
# 20            Cutoffs           None        NA                NA
# 20 2020-04-28 10:12:36.110557
# error!!!!!!!!!!!!!!!!!!!
# 21 2020-04-28 10:13:12.183649
#                 img_dir     style         top shape top pattern  \
# 0   codibook (1000).jpg    Formal   Long-sleeve-tee        None
# 1    codibook (801).jpg    Formal            Hoodie        None
# 2    codibook (802).jpg    Formal            Shirts     Graphic
# 3    codibook (803).jpg    Formal            Shirts       Check
# 4    codibook (804).jpg    Casual   Long-sleeve-tee     Graphic
# 5    codibook (805).jpg    Casual            Shirts       Check
# 6    codibook (806).jpg    Formal   Long-sleeve-tee        None
# 7    codibook (807).jpg    Casual   Long-sleeve-tee      Stripe
# 8    codibook (808).jpg    Casual   Long-sleeve-tee     Graphic
# 9    codibook (809).jpg    Casual   Long-sleeve-tee        None
# 10   codibook (810).jpg    Formal            Shirts       Check
# 11   codibook (811).jpg    Casual            Shirts        None
# 12   codibook (812).jpg    Formal  Short-sleeve-tee     Graphic
# 13   codibook (813).jpg    Casual                NA          NA
# 14   codibook (814).jpg    Formal                NA          NA
# 15   codibook (815).jpg    Casual                NA          NA
# 16   codibook (816).jpg  Feminine            Hoodie        None
# 17   codibook (817).jpg    Formal                NA          NA
# 18   codibook (818).jpg    Casual            Shirts      Stripe
# 19   codibook (819).jpg    Formal  Short-sleeve-tee        None
# 20   codibook (821).jpg  Feminine                NA          NA
# 22   codibook (823).jpg    Formal   Long-sleeve-tee        None
#
#          bottom shape bottom pattern one-piece one-piece pattern
# 0        H-line-skirt           None        NA                NA
# 1   Cotten-long-pants           None        NA                NA
# 2             Cutoffs           None        NA                NA
# 3               Jeans           None        NA                NA
# 4               Jeans           None        NA                NA
# 5   Cotten-long-pants           None        NA                NA
# 6        H-line-skirt          Check        NA                NA
# 7   Cotten-long-pants           None        NA                NA
# 8       Chiffon-skirt           None        NA                NA
# 9   Cotten-long-pants           None        NA                NA
# 10  Cotten-long-pants           None        NA                NA
# 11              Jeans           None        NA                NA
# 12  Cotten-long-pants           None        NA                NA
# 13  Cotten-long-pants           None        NA                NA
# 14            Cutoffs           None        NA                NA
# 15            Cutoffs          Check        NA                NA
# 16            Cutoffs           None        NA                NA
# 17  Cotten-long-pants           None        NA                NA
# 18            Cutoffs           None        NA                NA
# 19  Cotten-long-pants           None        NA                NA
# 20            Cutoffs           None        NA                NA
# 22            Cutoffs         Floral        NA                NA
# 22 2020-04-28 10:13:55.003167
#                 img_dir     style         top shape top pattern  \
# 0   codibook (1000).jpg    Formal   Long-sleeve-tee        None
# 1    codibook (801).jpg    Formal            Hoodie        None
# 2    codibook (802).jpg    Formal            Shirts     Graphic
# 3    codibook (803).jpg    Formal            Shirts       Check
# 4    codibook (804).jpg    Casual   Long-sleeve-tee     Graphic
# 5    codibook (805).jpg    Casual            Shirts       Check
# 6    codibook (806).jpg    Formal   Long-sleeve-tee        None
# 7    codibook (807).jpg    Casual   Long-sleeve-tee      Stripe
# 8    codibook (808).jpg    Casual   Long-sleeve-tee     Graphic
# 9    codibook (809).jpg    Casual   Long-sleeve-tee        None
# 10   codibook (810).jpg    Formal            Shirts       Check
# 11   codibook (811).jpg    Casual            Shirts        None
# 12   codibook (812).jpg    Formal  Short-sleeve-tee     Graphic
# 13   codibook (813).jpg    Casual                NA          NA
# 14   codibook (814).jpg    Formal                NA          NA
# 15   codibook (815).jpg    Casual                NA          NA
# 16   codibook (816).jpg  Feminine            Hoodie        None
# 17   codibook (817).jpg    Formal                NA          NA
# 18   codibook (818).jpg    Casual            Shirts      Stripe
# 19   codibook (819).jpg    Formal  Short-sleeve-tee        None
# 20   codibook (821).jpg  Feminine                NA          NA
# 22   codibook (823).jpg    Formal   Long-sleeve-tee        None
# 23   codibook (824).jpg    Casual   Long-sleeve-tee        None
#
#          bottom shape bottom pattern one-piece one-piece pattern
# 0        H-line-skirt           None        NA                NA
# 1   Cotten-long-pants           None        NA                NA
# 2             Cutoffs           None        NA                NA
# 3               Jeans           None        NA                NA
# 4               Jeans           None        NA                NA
# 5   Cotten-long-pants           None        NA                NA
# 6        H-line-skirt          Check        NA                NA
# 7   Cotten-long-pants           None        NA                NA
# 8       Chiffon-skirt           None        NA                NA
# 9   Cotten-long-pants           None        NA                NA
# 10  Cotten-long-pants           None        NA                NA
# 11              Jeans           None        NA                NA
# 12  Cotten-long-pants           None        NA                NA
# 13  Cotten-long-pants           None        NA                NA
# 14            Cutoffs           None        NA                NA
# 15            Cutoffs          Check        NA                NA
# 16            Cutoffs           None        NA                NA
# 17  Cotten-long-pants           None        NA                NA
# 18            Cutoffs           None        NA                NA
# 19  Cotten-long-pants           None        NA                NA
# 20            Cutoffs           None        NA                NA
# 22            Cutoffs         Floral        NA                NA
# 23              Jeans           None        NA                NA
# 23 2020-04-28 10:14:40.025660
#                 img_dir     style         top shape top pattern  \
# 0   codibook (1000).jpg    Formal   Long-sleeve-tee        None
# 1    codibook (801).jpg    Formal            Hoodie        None
# 2    codibook (802).jpg    Formal            Shirts     Graphic
# 3    codibook (803).jpg    Formal            Shirts       Check
# 4    codibook (804).jpg    Casual   Long-sleeve-tee     Graphic
# 5    codibook (805).jpg    Casual            Shirts       Check
# 6    codibook (806).jpg    Formal   Long-sleeve-tee        None
# 7    codibook (807).jpg    Casual   Long-sleeve-tee      Stripe
# 8    codibook (808).jpg    Casual   Long-sleeve-tee     Graphic
# 9    codibook (809).jpg    Casual   Long-sleeve-tee        None
# 10   codibook (810).jpg    Formal            Shirts       Check
# 11   codibook (811).jpg    Casual            Shirts        None
# 12   codibook (812).jpg    Formal  Short-sleeve-tee     Graphic
# 13   codibook (813).jpg    Casual                NA          NA
# 14   codibook (814).jpg    Formal                NA          NA
# 15   codibook (815).jpg    Casual                NA          NA
# 16   codibook (816).jpg  Feminine            Hoodie        None
# 17   codibook (817).jpg    Formal                NA          NA
# 18   codibook (818).jpg    Casual            Shirts      Stripe
# 19   codibook (819).jpg    Formal  Short-sleeve-tee        None
# 20   codibook (821).jpg  Feminine                NA          NA
# 22   codibook (823).jpg    Formal   Long-sleeve-tee        None
# 23   codibook (824).jpg    Casual   Long-sleeve-tee        None
# 24   codibook (825).jpg    Casual            Shirts        None
#
#          bottom shape bottom pattern one-piece one-piece pattern
# 0        H-line-skirt           None        NA                NA
# 1   Cotten-long-pants           None        NA                NA
# 2             Cutoffs           None        NA                NA
# 3               Jeans           None        NA                NA
# 4               Jeans           None        NA                NA
# 5   Cotten-long-pants           None        NA                NA
# 6        H-line-skirt          Check        NA                NA
# 7   Cotten-long-pants           None        NA                NA
# 8       Chiffon-skirt           None        NA                NA
# 9   Cotten-long-pants           None        NA                NA
# 10  Cotten-long-pants           None        NA                NA
# 11              Jeans           None        NA                NA
# 12  Cotten-long-pants           None        NA                NA
# 13  Cotten-long-pants           None        NA                NA
# 14            Cutoffs           None        NA                NA
# 15            Cutoffs          Check        NA                NA
# 16            Cutoffs           None        NA                NA
# 17  Cotten-long-pants           None        NA                NA
# 18            Cutoffs           None        NA                NA
# 19  Cotten-long-pants           None        NA                NA
# 20            Cutoffs           None        NA                NA
# 22            Cutoffs         Floral        NA                NA
# 23              Jeans           None        NA                NA
# 24              Jeans           None        NA                NA
# 24 2020-04-28 10:15:27.698841
#                 img_dir     style         top shape top pattern  \
# 0   codibook (1000).jpg    Formal   Long-sleeve-tee        None
# 1    codibook (801).jpg    Formal            Hoodie        None
# 2    codibook (802).jpg    Formal            Shirts     Graphic
# 3    codibook (803).jpg    Formal            Shirts       Check
# 4    codibook (804).jpg    Casual   Long-sleeve-tee     Graphic
# 5    codibook (805).jpg    Casual            Shirts       Check
# 6    codibook (806).jpg    Formal   Long-sleeve-tee        None
# 7    codibook (807).jpg    Casual   Long-sleeve-tee      Stripe
# 8    codibook (808).jpg    Casual   Long-sleeve-tee     Graphic
# 9    codibook (809).jpg    Casual   Long-sleeve-tee        None
# 10   codibook (810).jpg    Formal            Shirts       Check
# 11   codibook (811).jpg    Casual            Shirts        None
# 12   codibook (812).jpg    Formal  Short-sleeve-tee     Graphic
# 13   codibook (813).jpg    Casual                NA          NA
# 14   codibook (814).jpg    Formal                NA          NA
# 15   codibook (815).jpg    Casual                NA          NA
# 16   codibook (816).jpg  Feminine            Hoodie        None
# 17   codibook (817).jpg    Formal                NA          NA
# 18   codibook (818).jpg    Casual            Shirts      Stripe
# 19   codibook (819).jpg    Formal  Short-sleeve-tee        None
# 20   codibook (821).jpg  Feminine                NA          NA
# 22   codibook (823).jpg    Formal   Long-sleeve-tee        None
# 23   codibook (824).jpg    Casual   Long-sleeve-tee        None
# 24   codibook (825).jpg    Casual            Shirts        None
# 25   codibook (826).jpg    Casual   Long-sleeve-tee        None
#
#          bottom shape bottom pattern one-piece one-piece pattern
# 0        H-line-skirt           None        NA                NA
# 1   Cotten-long-pants           None        NA                NA
# 2             Cutoffs           None        NA                NA
# 3               Jeans           None        NA                NA
# 4               Jeans           None        NA                NA
# 5   Cotten-long-pants           None        NA                NA
# 6        H-line-skirt          Check        NA                NA
# 7   Cotten-long-pants           None        NA                NA
# 8       Chiffon-skirt           None        NA                NA
# 9   Cotten-long-pants           None        NA                NA
# 10  Cotten-long-pants           None        NA                NA
# 11              Jeans           None        NA                NA
# 12  Cotten-long-pants           None        NA                NA
# 13  Cotten-long-pants           None        NA                NA
# 14            Cutoffs           None        NA                NA
# 15            Cutoffs          Check        NA                NA
# 16            Cutoffs           None        NA                NA
# 17  Cotten-long-pants           None        NA                NA
# 18            Cutoffs           None        NA                NA
# 19  Cotten-long-pants           None        NA                NA
# 20            Cutoffs           None        NA                NA
# 22            Cutoffs         Floral        NA                NA
# 23              Jeans           None        NA                NA
# 24              Jeans           None        NA                NA
# 25      Chiffon-skirt          Check        NA                NA
# 25 2020-04-28 10:16:16.805410
#                 img_dir     style         top shape top pattern  \
# 0   codibook (1000).jpg    Formal   Long-sleeve-tee        None
# 1    codibook (801).jpg    Formal            Hoodie        None
# 2    codibook (802).jpg    Formal            Shirts     Graphic
# 3    codibook (803).jpg    Formal            Shirts       Check
# 4    codibook (804).jpg    Casual   Long-sleeve-tee     Graphic
# 5    codibook (805).jpg    Casual            Shirts       Check
# 6    codibook (806).jpg    Formal   Long-sleeve-tee        None
# 7    codibook (807).jpg    Casual   Long-sleeve-tee      Stripe
# 8    codibook (808).jpg    Casual   Long-sleeve-tee     Graphic
# ...
# 17   codibook (817).jpg    Formal                NA          NA
# 18   codibook (818).jpg    Casual            Shirts      Stripe
# 19   codibook (819).jpg    Formal  Short-sleeve-tee        None
# 20   codibook (821).jpg  Feminine                NA          NA
# 22   codibook (823).jpg    Formal   Long-sleeve-tee        None
# 23   codibook (824).jpg    Casual   Long-sleeve-tee        None
# 24   codibook (825).jpg    Casual            Shirts        None
# 25   codibook (826).jpg    Casual   Long-sleeve-tee        None
# 26   codibook (827).jpg    Formal                NA          NA
# 27   codibook (828).jpg    Formal                NA          NA
# 28   codibook (829).jpg    Casual   Long-sleeve-tee      Stripe
# 29   codibook (830).jpg    Formal  Short-sleeve-tee     Graphic
# 30   codibook (831).jpg    Formal                NA          NA
# 31   codibook (832).jpg    Formal  Short-sleeve-tee      Stripe
# 32   codibook (833).jpg    Formal            Hoodie        None
# 33   codibook (834).jpg  Feminine            Shirts       Check
# 34   codibook (835).jpg    Formal                NA          NA
# 35   codibook (836).jpg    Formal            Shirts       Check
# 36   codibook (837).jpg    Formal            Hoodie        None
# 37   codibook (838).jpg    Casual   Long-sleeve-tee        None
# 39   codibook (840).jpg    Casual   Long-sleeve-tee        None
# 40   codibook (841).jpg    Casual            Hoodie        None
# 41   codibook (842).jpg    Formal            Shirts      Floral
#
#          bottom shape bottom pattern  one-piece one-piece pattern
# 0        H-line-skirt           None         NA                NA
# 1   Cotten-long-pants           None         NA                NA
# 2             Cutoffs           None         NA                NA
# 3               Jeans           None         NA                NA
# 4               Jeans           None         NA                NA
# 5   Cotten-long-pants           None         NA                NA
# 6        H-line-skirt          Check         NA                NA
# 7   Cotten-long-pants           None         NA                NA
# 8       Chiffon-skirt           None         NA                NA
# 9   Cotten-long-pants           None         NA                NA
# 10  Cotten-long-pants           None         NA                NA
# 11              Jeans           None         NA                NA
# 12  Cotten-long-pants           None         NA                NA
# 13  Cotten-long-pants           None         NA                NA
# 14            Cutoffs           None         NA                NA
# 15            Cutoffs          Check         NA                NA
# 16            Cutoffs           None         NA                NA
# 17  Cotten-long-pants           None         NA                NA
# 18            Cutoffs           None         NA                NA
# 19  Cotten-long-pants           None         NA                NA
# 20            Cutoffs           None         NA                NA
# 22            Cutoffs         Floral         NA                NA
# 23              Jeans           None         NA                NA
# 24              Jeans           None         NA                NA
# 25      Chiffon-skirt          Check         NA                NA
# 26                 NA             NA  one-piece              None
# 27  Cotten-long-pants           None         NA                NA
# 28              Jeans           None         NA                NA
# 29            Cutoffs           None         NA                NA
# 30  Cotten-long-pants           None         NA                NA
# 31  Cotten-long-pants           None         NA                NA
# 32       H-line-skirt           None         NA                NA
# 33            Cutoffs         Floral         NA                NA
# 34            Cutoffs           None         NA                NA
# 35       H-line-skirt           None         NA                NA
# 36  Cotten-long-pants           None         NA                NA
# 37  Cotten-long-pants           None         NA                NA
# 39       H-line-skirt           None         NA                NA
# 40  Cotten-long-pants            Dot         NA                NA
# 41  Cotten-long-pants           None         NA                NA
# 41 2020-04-28 10:32:45.701146
#                 img_dir     style         top shape top pattern  \
# 0   codibook (1000).jpg    Formal   Long-sleeve-tee        None
# 1    codibook (801).jpg    Formal            Hoodie        None
# 2    codibook (802).jpg    Formal            Shirts     Graphic
# 3    codibook (803).jpg    Formal            Shirts       Check
# 4    codibook (804).jpg    Casual   Long-sleeve-tee     Graphic
# 5    codibook (805).jpg    Casual            Shirts       Check
# 6    codibook (806).jpg    Formal   Long-sleeve-tee        None
# 7    codibook (807).jpg    Casual   Long-sleeve-tee      Stripe
# 8    codibook (808).jpg    Casual   Long-sleeve-tee     Graphic
# 9    codibook (809).jpg    Casual   Long-sleeve-tee        None
# 10   codibook (810).jpg    Formal            Shirts       Check
# 11   codibook (811).jpg    Casual            Shirts        None
# 12   codibook (812).jpg    Formal  Short-sleeve-tee     Graphic
# 13   codibook (813).jpg    Casual                NA          NA
# 14   codibook (814).jpg    Formal                NA          NA
# 15   codibook (815).jpg    Casual                NA          NA
# 16   codibook (816).jpg  Feminine            Hoodie        None
# 17   codibook (817).jpg    Formal                NA          NA
# 18   codibook (818).jpg    Casual            Shirts      Stripe
# 19   codibook (819).jpg    Formal  Short-sleeve-tee        None
# 20   codibook (821).jpg  Feminine                NA          NA
# 22   codibook (823).jpg    Formal   Long-sleeve-tee        None
# 23   codibook (824).jpg    Casual   Long-sleeve-tee        None
# 24   codibook (825).jpg    Casual            Shirts        None
# 25   codibook (826).jpg    Casual   Long-sleeve-tee        None
# 26   codibook (827).jpg    Formal                NA          NA
# 27   codibook (828).jpg    Formal                NA          NA
# 28   codibook (829).jpg    Casual   Long-sleeve-tee      Stripe
# 29   codibook (830).jpg    Formal  Short-sleeve-tee     Graphic
# 30   codibook (831).jpg    Formal                NA          NA
# 31   codibook (832).jpg    Formal  Short-sleeve-tee      Stripe
# 32   codibook (833).jpg    Formal            Hoodie        None
# 33   codibook (834).jpg  Feminine            Shirts       Check
# 34   codibook (835).jpg    Formal                NA          NA
# 35   codibook (836).jpg    Formal            Shirts       Check
# 36   codibook (837).jpg    Formal            Hoodie        None
# 37   codibook (838).jpg    Casual   Long-sleeve-tee        None
# 39   codibook (840).jpg    Casual   Long-sleeve-tee        None
# 40   codibook (841).jpg    Casual            Hoodie        None
# 41   codibook (842).jpg    Formal            Shirts      Floral
# 42   codibook (843).jpg    Formal   Long-sleeve-tee        None
#
#          bottom shape bottom pattern  one-piece one-piece pattern
# 0        H-line-skirt           None         NA                NA
# 1   Cotten-long-pants           None         NA                NA
# 2             Cutoffs           None         NA                NA
# 3               Jeans           None         NA                NA
# 4               Jeans           None         NA                NA
# 5   Cotten-long-pants           None         NA                NA
# 6        H-line-skirt          Check         NA                NA
# 7   Cotten-long-pants           None         NA                NA
# 8       Chiffon-skirt           None         NA                NA
# 9   Cotten-long-pants           None         NA                NA
# 10  Cotten-long-pants           None         NA                NA
# 11              Jeans           None         NA                NA
# 12  Cotten-long-pants           None         NA                NA
# 13  Cotten-long-pants           None         NA                NA
# 14            Cutoffs           None         NA                NA
# 15            Cutoffs          Check         NA                NA
# 16            Cutoffs           None         NA                NA
# 17  Cotten-long-pants           None         NA                NA
# 18            Cutoffs           None         NA                NA
# 19  Cotten-long-pants           None         NA                NA
# 20            Cutoffs           None         NA                NA
# 22            Cutoffs         Floral         NA                NA
# 23              Jeans           None         NA                NA
# 24              Jeans           None         NA                NA
# 25      Chiffon-skirt          Check         NA                NA
# 26                 NA             NA  one-piece              None
# 27  Cotten-long-pants           None         NA                NA
# 28              Jeans           None         NA                NA
# 29            Cutoffs           None         NA                NA
# 30  Cotten-long-pants           None         NA                NA
# 31  Cotten-long-pants           None         NA                NA
# 32       H-line-skirt           None         NA                NA
# 33            Cutoffs         Floral         NA                NA
# 34            Cutoffs           None         NA                NA
# 35       H-line-skirt           None         NA                NA
# 36  Cotten-long-pants           None         NA                NA
# 37  Cotten-long-pants           None         NA                NA
# 39       H-line-skirt           None         NA                NA
# 40  Cotten-long-pants            Dot         NA                NA
# 41  Cotten-long-pants           None         NA                NA
# 42  Cotten-long-pants           None         NA                NA
# 42 2020-04-28 10:34:16.753436
#                 img_dir     style         top shape top pattern  \
# 0   codibook (1000).jpg    Formal   Long-sleeve-tee        None
# 1    codibook (801).jpg    Formal            Hoodie        None
# 2    codibook (802).jpg    Formal            Shirts     Graphic
# 3    codibook (803).jpg    Formal            Shirts       Check
# 4    codibook (804).jpg    Casual   Long-sleeve-tee     Graphic
# 5    codibook (805).jpg    Casual            Shirts       Check
# 6    codibook (806).jpg    Formal   Long-sleeve-tee        None
# 7    codibook (807).jpg    Casual   Long-sleeve-tee      Stripe
# 8    codibook (808).jpg    Casual   Long-sleeve-tee     Graphic
# 9    codibook (809).jpg    Casual   Long-sleeve-tee        None
# 10   codibook (810).jpg    Formal            Shirts       Check
# 11   codibook (811).jpg    Casual            Shirts        None
# 12   codibook (812).jpg    Formal  Short-sleeve-tee     Graphic
# 13   codibook (813).jpg    Casual                NA          NA
# 14   codibook (814).jpg    Formal                NA          NA
# 15   codibook (815).jpg    Casual                NA          NA
# 16   codibook (816).jpg  Feminine            Hoodie        None
# 17   codibook (817).jpg    Formal                NA          NA
# 18   codibook (818).jpg    Casual            Shirts      Stripe
# 19   codibook (819).jpg    Formal  Short-sleeve-tee        None
# 20   codibook (821).jpg  Feminine                NA          NA
# 22   codibook (823).jpg    Formal   Long-sleeve-tee        None
# 23   codibook (824).jpg    Casual   Long-sleeve-tee        None
# 24   codibook (825).jpg    Casual            Shirts        None
# 25   codibook (826).jpg    Casual   Long-sleeve-tee        None
# 26   codibook (827).jpg    Formal                NA          NA
# 27   codibook (828).jpg    Formal                NA          NA
# 28   codibook (829).jpg    Casual   Long-sleeve-tee      Stripe
# 29   codibook (830).jpg    Formal  Short-sleeve-tee     Graphic
# 30   codibook (831).jpg    Formal                NA          NA
# 31   codibook (832).jpg    Formal  Short-sleeve-tee      Stripe
# 32   codibook (833).jpg    Formal            Hoodie        None
# 33   codibook (834).jpg  Feminine            Shirts       Check
# 34   codibook (835).jpg    Formal                NA          NA
# 35   codibook (836).jpg    Formal            Shirts       Check
# 36   codibook (837).jpg    Formal            Hoodie        None
# 37   codibook (838).jpg    Casual   Long-sleeve-tee        None
# 39   codibook (840).jpg    Casual   Long-sleeve-tee        None
# 40   codibook (841).jpg    Casual            Hoodie        None
# 41   codibook (842).jpg    Formal            Shirts      Floral
# 42   codibook (843).jpg    Formal   Long-sleeve-tee        None
# 43   codibook (844).jpg    Casual                NA          NA
#
#          bottom shape bottom pattern  one-piece one-piece pattern
# 0        H-line-skirt           None         NA                NA
# 1   Cotten-long-pants           None         NA                NA
# 2             Cutoffs           None         NA                NA
# 3               Jeans           None         NA                NA
# 4               Jeans           None         NA                NA
# 5   Cotten-long-pants           None         NA                NA
# 6        H-line-skirt          Check         NA                NA
# 7   Cotten-long-pants           None         NA                NA
# 8       Chiffon-skirt           None         NA                NA
# 9   Cotten-long-pants           None         NA                NA
# 10  Cotten-long-pants           None         NA                NA
# 11              Jeans           None         NA                NA
# 12  Cotten-long-pants           None         NA                NA
# 13  Cotten-long-pants           None         NA                NA
# 14            Cutoffs           None         NA                NA
# 15            Cutoffs          Check         NA                NA
# 16            Cutoffs           None         NA                NA
# 17  Cotten-long-pants           None         NA                NA
# 18            Cutoffs           None         NA                NA
# 19  Cotten-long-pants           None         NA                NA
# 20            Cutoffs           None         NA                NA
# 22            Cutoffs         Floral         NA                NA
# 23              Jeans           None         NA                NA
# 24              Jeans           None         NA                NA
# 25      Chiffon-skirt          Check         NA                NA
# 26                 NA             NA  one-piece              None
# 27  Cotten-long-pants           None         NA                NA
# 28              Jeans           None         NA                NA
# 29            Cutoffs           None         NA                NA
# 30  Cotten-long-pants           None         NA                NA
# 31  Cotten-long-pants           None         NA                NA
# 32       H-line-skirt           None         NA                NA
# 33            Cutoffs         Floral         NA                NA
# 34            Cutoffs           None         NA                NA
# 35       H-line-skirt           None         NA                NA
# 36  Cotten-long-pants           None         NA                NA
# 37  Cotten-long-pants           None         NA                NA
# 39       H-line-skirt           None         NA                NA
# 40  Cotten-long-pants            Dot         NA                NA
# 41  Cotten-long-pants           None         NA                NA
# 42  Cotten-long-pants           None         NA                NA
# 43       H-line-skirt           None         NA                NA
# 43 2020-04-28 10:35:36.847805
# error!!!!!!!!!!!!!!!!!!!
# 44 2020-04-28 10:36:56.443211
