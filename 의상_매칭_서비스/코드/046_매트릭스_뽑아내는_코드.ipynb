# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./matrix_codibook_1000.csv')

# %%
ca_df = df[df['style']=='Casual']

# %%
ca_df.head()
# Out:
#               img_dir   style top shape top pattern       bottom shape  \
# 0    codibook (3).jpg  Casual       NaN         NaN  Cotten-long-pants
# 4    codibook (4).jpg  Casual    Shirts     Graphic       H-line-skirt
# 6    codibook (7).jpg  Casual       NaN         NaN  Cotten-long-pants
# 7   codibook (12).jpg  Casual       NaN         NaN       H-line-skirt
# 12  codibook (13).jpg  Casual    Shirts        None      Chiffon-skirt
#
#    bottom pattern one-piece one-piece pattern
# 0            None       NaN               NaN
# 4            None       NaN               NaN
# 6            None       NaN               NaN
# 7            None       NaN               NaN
# 12         Stripe       NaN               NaN

# %%
ca_df_2 = ca_df[['top shape','top pattern', 'bottom shape', 'bottom pattern']]

# %%
ca_df_3 = ca_df_2.dropna(axis = 0)

# %%
ca_df_3.head()
# Out:
#            top shape top pattern   bottom shape bottom pattern
# 4             Shirts     Graphic   H-line-skirt           None
# 12            Shirts        None  Chiffon-skirt         Stripe
# 14   Long-sleeve-tee        None  Chiffon-skirt           None
# 17   Long-sleeve-tee      Stripe        Cutoffs           None
# 19  Short-sleeve-tee      Stripe   H-line-skirt            Dot

# %%
ca_df_3['zeros'] = 1
# Out:
# C:\Users\student\Anaconda3\envs\cpu_env\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
f_df=ca_df_3.pivot_table('zeros',index=['top shape','top pattern'],columns=['bottom shape', 'bottom pattern'], aggfunc='count')

# %%
f_df
# Out:
# bottom shape                 Chiffon-skirt                                  \
# bottom pattern                       Check  Dot Floral Leopard None Stripe
# top shape        top pattern
# Hoodie           Check                 NaN  NaN    NaN     NaN  NaN    NaN
#                  Graphic               NaN  NaN    NaN     NaN  NaN    NaN
#                  None                  2.0  NaN    NaN     NaN  2.0    1.0
#                  Stripe                NaN  NaN    NaN     NaN  NaN    NaN
# Long-sleeve-tee  Check                 NaN  NaN    NaN     NaN  NaN    NaN
#                  Graphic               1.0  NaN    NaN     NaN  1.0    NaN
#                  None                  2.0  1.0    1.0     1.0  3.0    NaN
#                  Stripe                NaN  NaN    NaN     NaN  NaN    1.0
# Shirts           Check                 NaN  NaN    NaN     NaN  NaN    NaN
#                  Floral                NaN  NaN    NaN     NaN  NaN    NaN
# ...

# %%
f_df2 = f_df.fillna(0)

# %%
# 하의에 대한 상의 값 찾기
matched_upper = f_df2.xs(('Chiffon-skirt','None'), axis=1).sort_values(ascending=False).index[0]

matched_upper_shape = matched_upper[0]
matched_upper_pattern = matched_upper[1]

# %%
# 상의에 대한 하의 값 찾기
matched_lower = f_df2.loc[('Short-sleeve-tee','None')].sort_values(ascending=False).index[0]

matched_lower_shape = matched_upper[0]
matched_lower_pattern = matched_upper[1]
