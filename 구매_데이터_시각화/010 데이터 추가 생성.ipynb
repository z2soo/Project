# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 필요 모듈 import

# %%
# 필요한 module import

import random
import pandas as pd
import warnings
from dateutil.relativedelta import relativedelta
import datetime
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### 파일 불러오기 및 데이터 구조 확인

# %%
# 제대로 파일이 읽혔는지 확인

df01 = pd.read_csv("/content/drive/My Drive/SAP 5조 프로젝트/codefile/ZC05MMT001.csv")
display(df01.head())
df02 = pd.read_csv("/content/drive/My Drive/SAP 5조 프로젝트/codefile/ZC05MMT002.csv")
display(df02.head())
df03 = pd.read_csv("/content/drive/My Drive/SAP 5조 프로젝트/codefile/ZC05MMT003.csv")
display(df03.head())
# Out:
#    MANDT       EBELN       MATNR  EBELP  ...   ORT01       EINDT       BLDAT MBRSH
# 0    400  7900000001  CC-A08-F01      1  ...  Bremen  2016-01-10  2016-01-10     1
# 1    400  7900000001  CC-A08-R01      2  ...  Bremen  2016-01-10  2016-01-10     1
# 2    400  7900000001  CC-A08-R02      3  ...  Bremen  2016-01-10  2016-01-12     1
# 3    400  7900000001  CC-A08-R03      4  ...  Bremen  2016-01-10  2016-01-10     1
# 4    400  7900000001  CC-C07-F02      5  ...  Bremen  2016-01-10  2016-01-26     1
#
# [5 rows x 25 columns]
#       LIFNR       MATNR MTART  ... PPRICE MEINS WAERS
# 0  10300080  CC-A08-F01   ROH  ...    299    EA   USD
# 1  10300080  CC-A08-R01   ROH  ...    336    EA   USD
# 2  10300080  CC-A08-R02   ROH  ...    287    EA   USD
# 3  10300080  CC-A08-R03   ROH  ...    350    EA   USD
# 4  10300080  CC-C07-F02   ROH  ...    331    EA   USD
#
# [5 rows x 12 columns]
#         MATNR MBRSH                        MAKTX  ... AVPRICE      AVDATS WAERS
# ...

# %%
# 데이터 수 확인

print(len(df01))
print(len(df02))

# column명이랑 자재명 확인

print('\n=============================df01에 대한 확인===================================\n')
cols01 = df01.columns
print(f'{cols01}')

matnr01 = df01['MATNR'].unique()
# print(len(matnr01))                                  #table01 자재갯수가 100개 맞는지 확인: 맞음
maktx01 = df01['MAKTX'].unique()
# print(len(maktx01))

print('\n=============================df02에 대한 확인===================================\n')
cols02 = df02.columns
print(f'{cols02}')

matnr02 = df02['MATNR'].unique()
# print(len(matnr02))                                  #table01 자재갯수가 100개 맞는지 확인: 맞음

maktx02 = df02['MAKTX'].unique()
# print(len(maktx02))                                  #95개로 나와서 수정 필요
# Out:
# 3600
# 3600
#
# =============================df01에 대한 확인===================================
#
# Index(['MANDT', 'EBELN', 'MATNR', 'EBELP', 'MAKTX', 'MTART', 'WERKS', 'MEINS',
#        'NETPR', 'BRTWR', 'AEDAT', 'RETPO', 'LIFNR', 'EKORG', 'WAERS', 'TELF1',
#        'BEDAT', 'WEMNG', 'MENGE', 'NAME1', 'LAND1', 'ORT01', 'EINDT', 'BLDAT',
#        'MBRSH'],
#       dtype='object')
#
# =============================df02에 대한 확인===================================
#
# Index(['LIFNR', 'MATNR', 'MTART', 'MAKTX', 'NAME1', 'MBRSH', 'TPPRICE',
#        'TPAMOUNT', 'PDATE', 'PPRICE', 'MEINS', 'WAERS'],
#       dtype='object')

# %% [markdown]
# ### 중복되는 자재번호 변경해서 zc05mmt02, zc05mmt03 다시 저장

# %%
# 자재번호는 다른데 자재명이 동일한 경우가 있어서 이에 대한 수정 필요: table02

for _ in range(len(df02)):
    if df02['MATNR'][_] == 'CT-R01':
        df02['MAKTX'][_] = 'Iris Recognition Sensor(IRS)'
    elif df02['MATNR'][_] == 'CT-R02':
        df02['MAKTX'][_] = 'Nano Semiconductor(NS)'
    elif df02['MATNR'][_] == 'CT-R03':
        df02['MAKTX'][_] = 'Bluetooth Semiconductor(BS)'
    elif df02['MATNR'][_] == 'CT-R04':
        df02['MAKTX'][_] = 'VR Base Frame'
    elif df02['MATNR'][_] == 'CT-R05':
        df02['MAKTX'][_] = 'Virtualization Lens(VL)'

# 자재명 100인지 확인        
print(len(df02['MAKTX'].unique()))
        
# xlsx 파일로 저장
result02 = pd.DataFrame(df02)
result02.to_excel(excel_writer='/content/drive/My Drive/SAP 5조 프로젝트/codefile/ZC05MMT002.xlsx', header=True, index=False)
# Out:
# 100

# %%
# 자재번호는 다른데 자재명이 동일한 경우가 있어서 이에 대한 수정 필요: table03

for _ in range(len(df03)):
    if df03['MATNR'][_] == 'CT-R01':
        df03['MAKTX'][_] = 'Iris Recognition Sensor(IRS)'
    elif df03['MATNR'][_] == 'CT-R02':
        df03['MAKTX'][_] = 'Nano Semiconductor(NS)'
    elif df03['MATNR'][_] == 'CT-R03':
        df03['MAKTX'][_] = 'Bluetooth Semiconductor(BS)'
    elif df03['MATNR'][_] == 'CT-R04':
        df03['MAKTX'][_] = 'VR Base Frame'
    elif df03['MATNR'][_] == 'CT-R05':
        df03['MAKTX'][_] = 'Virtualization Lens(VL)'

# 자재명 100인지 확인        
print(len(df03['MAKTX'].unique()))
        
# xlsx 파일로 저장
result03 = pd.DataFrame(df03)
result03.to_excel(excel_writer='/content/drive/My Drive/SAP 5조 프로젝트/codefile/ZC05MMT003.xlsx', header=True, index=False)
# Out:
# 100

# %% [markdown]
# ### 추가 데이터를 생성해보자

# %%
# 자재번호를 이름순으로 sort
# 공급업체 리스트 생성
# 자재번호 하나당 공급업체 리스트 값의 한 값으로 3년치 데이터 생성

# %%
# 추가 데이터 넣을 테이블 생성

dfAdd = pd.DataFrame()
for col in df01.columns:
    dfAdd[col] = 'NA'
display(dfAdd)

# 자재명 리스트
maktxList = df01['MAKTX'].unique()
maktxList.sort()
#print(maktxList, len(maktxList))

# df01 한번 뽑아보기
df01.iloc[:10]
# Out:
# Empty DataFrame
# Columns: [MANDT, EBELN, MATNR, EBELP, MAKTX, MTART, WERKS, MEINS, NETPR, BRTWR, AEDAT, RETPO, LIFNR, EKORG, WAERS, TELF1, BEDAT, WEMNG, MENGE, NAME1, LAND1, ORT01, EINDT, BLDAT, MBRSH]
# Index: []
#    MANDT       EBELN       MATNR  EBELP  ...     ORT01       EINDT       BLDAT MBRSH
# 0    400  7900000001  CC-A08-F01      1  ...    Bremen  2016-01-10  2016-01-10     1
# 1    400  7900000001  CC-A08-R01      2  ...    Bremen  2016-01-10  2016-01-10     1
# 2    400  7900000001  CC-A08-R02      3  ...    Bremen  2016-01-10  2016-01-12     1
# 3    400  7900000001  CC-A08-R03      4  ...    Bremen  2016-01-10  2016-01-10     1
# 4    400  7900000001  CC-C07-F02      5  ...    Bremen  2016-01-10  2016-01-26     1
# 5    400  7900000002  CC-D28-F01      1  ...  New York  2016-01-10  2016-01-10     1
# 6    400  7900000002      CT-F01      2  ...  New York  2016-01-10  2016-01-10     1
# 7    400  7900000002      CT-H01      3  ...  New York  2016-01-10  2016-01-10     1
# ...

# %%
dfAdd.columns

# %%
# 공급업체 리스트 정보 가져오기

df04 = pd.read_csv("/content/drive/My Drive/SAP 5조 프로젝트/codefile/ZC05MMT004.csv")
display(df04.head())
df04 = df04.drop(['COMT'], axis=1)                     #필요없는 코멘트 컬럼 삭제
display(df04.head())
df04 = df04.drop_duplicates()                          #중복 값 제거
print(f'공급업체 갯수: {len(df04)}')                   #순수하게 20개의 공급업체 정보만 남음
dfOrg = df04

orgList = dfOrg['LIFNR'].unique()
# Out:
#       LIFNR  ...                                               COMT
# 0  10300080  ...  Had all the parts, with power tools it took ab...
# 1  10300080  ...  Delivered fast. Takes about 6hrs to assemble b...
# 2  10300080  ...  Absolutely amazing! I had the first Generation...
# 3  10300080  ...  They were absolutely great love everything abo...
# 4  10300080  ...  I enjoy using my airpods pros they have great ...
#
# [5 rows x 5 columns]
#       LIFNR                                NAME1 LAND1   ORT01
# 0  10300080  Inlandslieferant DE (Ariba Netzwerk    DE  Bremen
# 1  10300080  Inlandslieferant DE (Ariba Netzwerk    DE  Bremen
# 2  10300080  Inlandslieferant DE (Ariba Netzwerk    DE  Bremen
# 3  10300080  Inlandslieferant DE (Ariba Netzwerk    DE  Bremen
# 4  10300080  Inlandslieferant DE (Ariba Netzwerk    DE  Bremen
# 공급업체 갯수: 20

# %%
df02.tail()
# Out:
#            LIFNR      MATNR MTART         MAKTX  ...       PDATE PPRICE  MEINS  WAERS
# 3595  9980000137   DS_RAW02   ROH         Locks  ...  2018-12-01    433     EA    USD
# 3596  9980000137   DUMMY-FG   ROH         Horns  ...  2018-12-01    473     EA    USD
# 3597  9980000137   DUMMY-RM   ROH  Bottle Cages  ...  2018-12-01    429     EA    USD
# 3598  9980000137       FG29   ROH     Indicator  ...  2018-12-01    440     EA    USD
# 3599  9980000137  ML-CEMENT   ROH        CEMENT  ...  2018-12-01    440     EA    USD
#
# [5 rows x 12 columns]

# %%
i = int(7900000721)    #이전 마지막 EBELN+1
print(i)

# 날짜 설정
# aedat = datetime.datetime.strptime('2016-01-01', "%Y-%m-%d").date() #구매오더 변경날짜
# bedat = datetime.datetime.strptime('2016-01-01', "%Y-%m-%d").date() #구매오더 생성일        
# eindt = datetime.datetime.strptime('2016-01-10', "%Y-%m-%d").date() #납품요청일
            
            
for _ in range(len(maktxList)):
    mName = maktxList[_]
    myDict = {'MANDT': '400',
              'EBELN': 'NA',          #구매문서번호
              'MATNR': 'NA',       #자재번호
              'EBELP': '1', 
              'MAKTX': mName,          #자재명
              'MTART': 'NA',       #자재유형명
              'WERKS': '1710', 
              'MEINS': 'EA',
              'NETPR': 'NA',       #구매문서단가
              'BRTWR': 'NA',       #총구매금액
              'AEDAT': 'NA',       #구매오더 변경날짜
              'RETPO': 'NA',       #반품품목
              'LIFNR': 'NA',       #공급업체번호
              'EKORG': '1710', 
              'WAERS': 'USD', 
              'TELF1': 'NA',       #공급업체전화번호
              'BEDAT': 'NA',       #구매오더 생성일: 변경날짜와 동일
              'WEMNG': 'NA',       #납품입고수량
              'MENGE': 'NA',       #납품예정수량
              'NAME1': 'NA',       #공급업체명
              'LAND1': 'NA',       #공급업체주소날짜
              'ORT01': 'NA',       #공급업체주소도시
              'EINDT': 'NA',       #납품요청일
              'BLDAT': 'NA',       #전표증빙일
              'MBRSH': 'NA'        #산업부문
             }
    
    #하나의 자재에 대해서 공급업체 하나 정해서 3년치 월별 정보 생성
    for t in range(len(orgList)):        #공급업체번호: 동일 자재가 동일한 공급업체와 매칭되지 않도록 피해주기
        org = orgList[t]   
        print(f'자재명:{mName} & 공급업체명:{org}')

        #공급업체번호
        mIndex = df01.index[df01['MAKTX'] == mName].tolist()                 #해당 자재명의 인덱스
        oIndex = df01.index[df01['LIFNR'] == org].tolist()                   #해당 공급업체명의 인덱스
        

        aedat = datetime.datetime.strptime('2016-01-01', "%Y-%m-%d").date() #구매오더 변경날짜
        bedat = datetime.datetime.strptime('2016-01-01', "%Y-%m-%d").date() #구매오더 생성일        
        eindt = datetime.datetime.strptime('2016-01-10', "%Y-%m-%d").date() #납품요청일

        if mIndex != oIndex: 
   
            for y in range(36):

                lifnr = org     
                
#                 aedat = datetime.datetime.strptime(date01, "%Y-%m-%d").date() #구매오더 변경날짜
#                 bedat = datetime.datetime.strptime(date01, "%Y-%m-%d").date() #구매오더 생성일        
#                 eindt = datetime.datetime.strptime(date10, "%Y-%m-%d").date() #납품요청일

                # 납품요청일을 기준으로 랜덤 날짜를 더해 전표 증빙일 생성    
                var3 = random.randint(0,6)                                  
                myList = [0,0,0,0,0,0, random.randint(-8,20)]                
                bldat = eindt + datetime.timedelta(days = myList[var3])
#                 bldat = datetime.datetime.strptime(bldat, "%Y-%m-%d").date() #전표증빙일

                myDict.update(LIFNR = lifnr)      #공급업체번호        
                myDict.update(AEDAT = aedat)      #구매오더 변경날짜
                myDict.update(BEDAT = bedat)       #구매오더 생성일: 변경날짜와 동일        
                myDict.update(EINDT = eindt)       #납품요청일
                myDict.update(BLDAT = bldat)       #전표증빙일
                myDict.update(EBELN = i)  
                
                dict_values = list(myDict.values())
                dfAdd = dfAdd.append(pd.Series(dict_values, index=dfAdd.columns), ignore_index=True)
                           
                aedat += relativedelta(months = 1)
                bedat += relativedelta(months = 1)
                eindt += relativedelta(months = 1)
                
                i += 1
    print(f'{len(maktxList)} 중 {_}번째 자재: {mName} 완료') 
    # 혹시 모를 오류를 위해 xlsx 파일로 저장
    result = pd.DataFrame(dfAdd)
    filename = str('result') + str('0') + str(_) + str(mName) + str('.xlsx')
    result.to_excel(excel_writer=filename, header=True, index=False)

result.to_excel(excel_writer='/content/drive/My Drive/SAP 5조 프로젝트/codefile/totaldata.xlsx', header=True, index=False)

# %%
len(dfAdd)
# Out:
# 72000

# %% [markdown]
# ### 비어있는 부분 채워주기

# %%
dfAdd = pd.read_csv("/content/drive/My Drive/SAP 5조 프로젝트/codefile/totaldata.csv")
display(dfAdd.head())
# Out:
#    MANDT       EBELN  MATNR  EBELP  ... ORT01       EINDT       BLDAT MBRSH
# 0    400  7900000721    NaN      1  ...   NaN  2016-01-10  2016-01-10   NaN
# 1    400  7900000722    NaN      1  ...   NaN  2016-02-10  2016-02-10   NaN
# 2    400  7900000723    NaN      1  ...   NaN  2016-03-10  2016-03-10   NaN
# 3    400  7900000724    NaN      1  ...   NaN  2016-04-10  2016-04-10   NaN
# 4    400  7900000725    NaN      1  ...   NaN  2016-05-10  2016-05-10   NaN
#
# [5 rows x 25 columns]

# %%
dfAdd.columns

#TELF1 컬럼 삭제
dfAdd = dfAdd.drop(['TELF1'], axis=1)
display(dfAdd.head())
# Out:
#    MANDT       EBELN  MATNR  EBELP  ... ORT01       EINDT       BLDAT MBRSH
# 0    400  7900000721    NaN      1  ...   NaN  2016-01-10  2016-01-10   NaN
# 1    400  7900000722    NaN      1  ...   NaN  2016-02-10  2016-02-10   NaN
# 2    400  7900000723    NaN      1  ...   NaN  2016-03-10  2016-03-10   NaN
# 3    400  7900000724    NaN      1  ...   NaN  2016-04-10  2016-04-10   NaN
# 4    400  7900000725    NaN      1  ...   NaN  2016-05-10  2016-05-10   NaN
#
# [5 rows x 24 columns]

# %%
# 자재 정보 테이블: dfMat
dfMat = df01[['MAKTX','MATNR','MTART']]
dfMat = dfMat.drop_duplicates(['MAKTX','MATNR','MTART'])
display(dfMat.head())
matnr = dfMat['MATNR'].unique()
print(len(matnr))

# 공급업체 정보 테이블: dfOrg
display(dfOrg.head())
# Out:
#                          MAKTX       MATNR MTART
# 0              Cross Racer 3.0  CC-A08-F01   ROH
# 1                   Bike Paint  CC-A08-R01   ROH
# 2          USB Adapter USB-901  CC-A08-R02   ROH
# 3  1ortable DVD Player PDP-121  CC-A08-R03   ROH
# 4                    Headlight  CC-C07-F02   ROH
# 100
#          LIFNR  ...                   ORT01
# 0     10300080  ...                  Bremen
# 5   USSU-VSF22  ...                New York
# 10      USSU01  ...                 Atlanta
# 15  USSU-VSF50  ...                 Atlanta
# 20     1000126  ...  Goyang-si, Gyeonggi-do
#
# [5 rows x 4 columns]

# %%
# 정보 추가하기

print(len(dfAdd.columns))
print(dfAdd.columns)

dfAdd = pd.merge(dfAdd, dfOrg, on='LIFNR')
dfAdd = pd.merge(dfAdd, dfMat, on='MAKTX')
dfAdd.head()
# Out:
# 24
# Index(['MANDT', 'EBELN', 'MATNR', 'EBELP', 'MAKTX', 'MTART', 'WERKS', 'MEINS',
#        'NETPR', 'BRTWR', 'AEDAT', 'RETPO', 'LIFNR', 'EKORG', 'WAERS', 'BEDAT',
#        'WEMNG', 'MENGE', 'NAME1', 'LAND1', 'ORT01', 'EINDT', 'BLDAT', 'MBRSH'],
#       dtype='object')
#    MANDT       EBELN  MATNR_x  EBELP  ... LAND1_y  ORT01_y     MATNR_y MTART_y
# 0    400  7900000721      NaN      1  ...      DE   Bremen  CC-A08-R03     ROH
# 1    400  7900000722      NaN      1  ...      DE   Bremen  CC-A08-R03     ROH
# 2    400  7900000723      NaN      1  ...      DE   Bremen  CC-A08-R03     ROH
# 3    400  7900000724      NaN      1  ...      DE   Bremen  CC-A08-R03     ROH
# 4    400  7900000725      NaN      1  ...      DE   Bremen  CC-A08-R03     ROH
#
# [5 rows x 29 columns]

# %%
# 중복되는 컬럼 지우고 컬럼명 변경

print(len(dfAdd.columns))
print(dfAdd.columns)

# 중복 컬럼 삭제
dfAdd = dfAdd.drop(['MATNR_x', 'MTART_x','NAME1_x','LAND1_x','ORT01_x'], axis=1)
display(dfAdd.head())

# 컬럼명 재설정
dfAdd = dfAdd.rename({'NAME1_y': 'NAME1', 
                      'LAND1_y': 'LAND1',
                      'ORT01_y': 'ORT01',
                      'MATNR_y': 'MATNR',
                      'MTART_y': 'MTART'}, axis='columns')
display(dfAdd.head())
# Out:
# 29
# Index(['MANDT', 'EBELN', 'MATNR_x', 'EBELP', 'MAKTX', 'MTART_x', 'WERKS',
#        'MEINS', 'NETPR', 'BRTWR', 'AEDAT', 'RETPO', 'LIFNR', 'EKORG', 'WAERS',
#        'BEDAT', 'WEMNG', 'MENGE', 'NAME1_x', 'LAND1_x', 'ORT01_x', 'EINDT',
#        'BLDAT', 'MBRSH', 'NAME1', 'LAND1', 'ORT01', 'MATNR', 'MTART'],
#       dtype='object')
#    MANDT       EBELN  EBELP  ...   ORT01       MATNR MTART
# 0    400  7900000721      1  ...  Bremen  CC-A08-R03   ROH
# 1    400  7900000722      1  ...  Bremen  CC-A08-R03   ROH
# 2    400  7900000723      1  ...  Bremen  CC-A08-R03   ROH
# 3    400  7900000724      1  ...  Bremen  CC-A08-R03   ROH
# 4    400  7900000725      1  ...  Bremen  CC-A08-R03   ROH
#
# [5 rows x 24 columns]
#    MANDT       EBELN  EBELP  ...   ORT01       MATNR MTART
# 0    400  7900000721      1  ...  Bremen  CC-A08-R03   ROH
# 1    400  7900000722      1  ...  Bremen  CC-A08-R03   ROH
# 2    400  7900000723      1  ...  Bremen  CC-A08-R03   ROH
# ...

# %% [markdown]
# ### 가격정보 추가

# %%
# 구매문서의 단가 NETPR

for _ in range(len(dfAdd)):
    a = random.randint(-70,70)
    b = random.randint(-10,10)
    c = random.randint(-30,30)
    d = random.randint(-100,100)
    e = random.randint(-150,150)
    
    if dfAdd['MATNR'][_] in [ matnr[0], matnr[1], matnr[2], matnr[3], matnr[4], matnr[5], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        dfAdd['NETPR'][_] = 300 + a
    elif dfAdd['MATNR'][_] in [ matnr[10], matnr[11], matnr[12], matnr[13], matnr[14], matnr[15], 
                                     matnr[16], matnr[17], matnr[18], matnr[19]]:
        dfAdd['NETPR'][_] = 300 + a
    elif dfAdd['MATNR'][_] in [ matnr[20], matnr[21], matnr[22], matnr[23], matnr[24], matnr[25], 
                                     matnr[26], matnr[27], matnr[28], matnr[29]]:
        dfAdd['NETPR'][_] = 500 + b
    elif dfAdd['MATNR'][_] in [ matnr[30], matnr[31], matnr[32], matnr[33], matnr[34], matnr[35], 
                                     matnr[36], matnr[37], matnr[38], matnr[39]]:
        dfAdd['NETPR'][_] = 800 + c
    elif dfAdd['MATNR'][_] in [ matnr[40], matnr[41], matnr[42], matnr[43], matnr[44], matnr[45], 
                                     matnr[46], matnr[47], matnr[48], matnr[49]]:
        dfAdd['NETPR'][_] = 1000 + d
    elif dfAdd['MATNR'][_] in [ matnr[50], matnr[51], matnr[52], matnr[53], matnr[54], matnr[55], 
                                     matnr[56], matnr[57], matnr[58], matnr[59]]:
        dfAdd['NETPR'][_] = 750 + a
    elif dfAdd['MATNR'][_] in [ matnr[60], matnr[61], matnr[62], matnr[63], matnr[64], matnr[65], 
                                     matnr[66], matnr[67], matnr[68], matnr[69]]:
        dfAdd['NETPR'][_] = 900 + d
    elif dfAdd['MATNR'][_] in [ matnr[70], matnr[71], matnr[72], matnr[73], matnr[74], matnr[75], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        dfAdd['NETPR'][_] = 950 + c
    elif dfAdd['MATNR'][_] in [ matnr[80], matnr[81], matnr[82], matnr[83], matnr[84], matnr[85], 
                                     matnr[86], matnr[87], matnr[88], matnr[89]]:
        dfAdd['NETPR'][_] = 1500 + e
    else:
        dfAdd['NETPR'][_] = 450 + c

# %%
display(dfAdd.head())
display(dfAdd.tail())
# Out:
#    MANDT       EBELN  EBELP  ...   ORT01       MATNR MTART
# 0    400  7900000721      1  ...  Bremen  CC-A08-R03   ROH
# 1    400  7900000722      1  ...  Bremen  CC-A08-R03   ROH
# 2    400  7900000723      1  ...  Bremen  CC-A08-R03   ROH
# 3    400  7900000724      1  ...  Bremen  CC-A08-R03   ROH
# 4    400  7900000725      1  ...  Bremen  CC-A08-R03   ROH
#
# [5 rows x 24 columns]
#        MANDT       EBELN  EBELP       MAKTX  ...  LAND1     ORT01        MATNR  MTART
# 71995    400  7900072716      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
# 71996    400  7900072717      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
# 71997    400  7900072718      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
# 71998    400  7900072719      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
# 71999    400  7900072720      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
#
# [5 rows x 24 columns]

# %%
# 납품예정수량 MENGE

for _ in range(len(dfAdd)):
    a = random.randint(-1000,1000)
    b = random.randint(0,5000)
    c = random.randint(-40,80)
    d = random.randint(0,1000)
    e = random.randint(-90,110)
    f = random.randint(-400, 500)
    
    if dfAdd['MATNR'][_] in [ matnr[0], matnr[1], matnr[2], matnr[3], matnr[4], matnr[5], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        dfAdd['MENGE'][_] = 1000 + c
    elif dfAdd['MATNR'][_] in [ matnr[10], matnr[11], matnr[12], matnr[13], matnr[14], matnr[15], 
                                     matnr[16], matnr[17], matnr[18], matnr[19]]:
        dfAdd['MENGE'][_] = 3000 + f
    elif dfAdd['MATNR'][_] in [ matnr[20], matnr[21], matnr[22], matnr[23], matnr[24], matnr[25], 
                                     matnr[26], matnr[27], matnr[28], matnr[29]]:
        dfAdd['MENGE'][_] = 5000 + a
    elif dfAdd['MATNR'][_] in [ matnr[30], matnr[31], matnr[32], matnr[33], matnr[34], matnr[35], 
                                     matnr[36], matnr[37], matnr[38], matnr[39]]:
        dfAdd['MENGE'][_] = 8000 + a
    elif dfAdd['MATNR'][_] in [ matnr[40], matnr[41], matnr[42], matnr[43], matnr[44], matnr[45], 
                                     matnr[46], matnr[47], matnr[48], matnr[49]]:
        dfAdd['MENGE'][_] = 1000 + f
    elif dfAdd['MATNR'][_] in [ matnr[50], matnr[51], matnr[52], matnr[53], matnr[54], matnr[55], 
                                     matnr[56], matnr[57], matnr[58], matnr[59]]:
        dfAdd['MENGE'][_] = 750 + c
    elif dfAdd['MATNR'][_] in [ matnr[60], matnr[61], matnr[62], matnr[63], matnr[64], matnr[65], 
                                     matnr[66], matnr[67], matnr[68], matnr[69]]:
        dfAdd['MENGE'][_] = 3000 + b
    elif dfAdd['MATNR'][_] in [ matnr[70], matnr[71], matnr[72], matnr[73], matnr[74], matnr[75], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        dfAdd['MENGE'][_] = 1500 + f
    elif dfAdd['MATNR'][_] in [ matnr[80], matnr[81], matnr[82], matnr[83], matnr[84], matnr[85], 
                                     matnr[86], matnr[87], matnr[88], matnr[89]]:
        dfAdd['MENGE'][_] = 1500 + d
    else:
        dfAdd['MENGE'][_] = 450 + c

# %%
display(dfAdd.head())
display(dfAdd.tail())
# Out:
#    MANDT       EBELN  EBELP  ...   ORT01       MATNR MTART
# 0    400  7900000721      1  ...  Bremen  CC-A08-R03   ROH
# 1    400  7900000722      1  ...  Bremen  CC-A08-R03   ROH
# 2    400  7900000723      1  ...  Bremen  CC-A08-R03   ROH
# 3    400  7900000724      1  ...  Bremen  CC-A08-R03   ROH
# 4    400  7900000725      1  ...  Bremen  CC-A08-R03   ROH
#
# [5 rows x 24 columns]
#        MANDT       EBELN  EBELP       MAKTX  ...  LAND1     ORT01        MATNR  MTART
# 71995    400  7900072716      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
# 71996    400  7900072717      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
# 71997    400  7900072718      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
# 71998    400  7900072719      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
# 71999    400  7900072720      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
#
# [5 rows x 24 columns]

# %%
# 납품입고수량 WEMNG: 예정 수량을 기준으로 랜덤 값을 빼줌

for _ in range(len(dfAdd)):
    #a = random.randint(-500,0)
    #b = random.randint(-1000,0)
    #c = random.randint(-50,0)
    #d = random.randint(-100,0)
    #e = random.randint(-300,0) 
    a = [0,0,0,0,0, random.randint(-500,0)]               #배열 속 0 갯수 또한 랜덤으로 들어가도록 설정해줘도 좋을 듯!!
    b = [0,0,0,0,0, random.randint(-1000,0)]
    c = [0,0,0,0,0, random.randint(-50,0)]
    d = [0,0,0,0,0, random.randint(-100,0)] 
    e = [0,0,0,0,0, random.randint(-300,0)]
    

    if dfAdd['MATNR'][_] in [ matnr[0], matnr[1], matnr[2], matnr[3], matnr[4], matnr[5], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        dfAdd['WEMNG'][_] =  dfAdd['MENGE'][_] + a[random.randint(0,5)]    
    elif dfAdd['MATNR'][_] in [ matnr[10], matnr[11], matnr[12], matnr[13], matnr[14], matnr[15], 
                                     matnr[16], matnr[17], matnr[18], matnr[19]]:
        dfAdd['WEMNG'][_] =  dfAdd['MENGE'][_] + a[random.randint(0,5)]     
    elif dfAdd['MATNR'][_] in [ matnr[20], matnr[21], matnr[22], matnr[23], matnr[24], matnr[25], 
                                     matnr[26], matnr[27], matnr[28], matnr[29]]:
        dfAdd['WEMNG'][_] =  dfAdd['MENGE'][_] + b[random.randint(0,5)]     
    elif dfAdd['MATNR'][_] in [ matnr[30], matnr[31], matnr[32], matnr[33], matnr[34], matnr[35], 
                                     matnr[36], matnr[37], matnr[38], matnr[39]]:
        dfAdd['WEMNG'][_] =  dfAdd['MENGE'][_] + b[random.randint(0,5)]    
    elif dfAdd['MATNR'][_] in [ matnr[40], matnr[41], matnr[42], matnr[43], matnr[44], matnr[45], 
                                     matnr[46], matnr[47], matnr[48], matnr[49]]:
        dfAdd['WEMNG'][_] =  dfAdd['MENGE'][_] + c[random.randint(0,5)]     
    elif dfAdd['MATNR'][_] in [ matnr[50], matnr[51], matnr[52], matnr[53], matnr[54], matnr[55], 
                                     matnr[56], matnr[57], matnr[58], matnr[59]]:
        dfAdd['WEMNG'][_] =  dfAdd['MENGE'][_] + c[random.randint(0,5)]     
    elif dfAdd['MATNR'][_] in [ matnr[60], matnr[61], matnr[62], matnr[63], matnr[64], matnr[65], 
                                     matnr[66], matnr[67], matnr[68], matnr[69]]:
        dfAdd['WEMNG'][_] =  dfAdd['MENGE'][_] + e[random.randint(0,5)]    
    elif dfAdd['MATNR'][_] in [ matnr[70], matnr[71], matnr[72], matnr[73], matnr[74], matnr[75], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        dfAdd['WEMNG'][_] =  dfAdd['MENGE'][_] + a[random.randint(0,5)]     
    elif dfAdd['MATNR'][_] in [ matnr[80], matnr[81], matnr[82], matnr[83], matnr[84], matnr[85], 
                                     matnr[86], matnr[87], matnr[88], matnr[89]]:
        dfAdd['WEMNG'][_] =  dfAdd['MENGE'][_] + e[random.randint(0,5)]     
    else:
        dfAdd['WEMNG'][_] =  dfAdd['MENGE'][_] + c[random.randint(0,5)]

# %%
display(dfAdd.head())
display(dfAdd.tail())
# Out:
#    MANDT       EBELN  EBELP  ...   ORT01       MATNR MTART
# 0    400  7900000721      1  ...  Bremen  CC-A08-R03   ROH
# 1    400  7900000722      1  ...  Bremen  CC-A08-R03   ROH
# 2    400  7900000723      1  ...  Bremen  CC-A08-R03   ROH
# 3    400  7900000724      1  ...  Bremen  CC-A08-R03   ROH
# 4    400  7900000725      1  ...  Bremen  CC-A08-R03   ROH
#
# [5 rows x 24 columns]
#        MANDT       EBELN  EBELP       MAKTX  ...  LAND1     ORT01        MATNR  MTART
# 71995    400  7900072716      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
# 71996    400  7900072717      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
# 71997    400  7900072718      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
# 71998    400  7900072719      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
# 71999    400  7900072720      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
#
# [5 rows x 24 columns]

# %%
# 총구매금액 BRTWR: 구매문서의 단가 NETPR * 납품예정수량 MENGE

for _ in range(len(dfAdd)):
    dfAdd['BRTWR'][_] = dfAdd['NETPR'][_] * dfAdd['MENGE'][_]

# %%
display(dfAdd.head())
display(dfAdd.tail())
# Out:
#    MANDT       EBELN  EBELP  ...   ORT01       MATNR MTART
# 0    400  7900000721      1  ...  Bremen  CC-A08-R03   ROH
# 1    400  7900000722      1  ...  Bremen  CC-A08-R03   ROH
# 2    400  7900000723      1  ...  Bremen  CC-A08-R03   ROH
# 3    400  7900000724      1  ...  Bremen  CC-A08-R03   ROH
# 4    400  7900000725      1  ...  Bremen  CC-A08-R03   ROH
#
# [5 rows x 24 columns]
#        MANDT       EBELN  EBELP       MAKTX  ...  LAND1     ORT01        MATNR  MTART
# 71995    400  7900072716      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
# 71996    400  7900072717      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
# 71997    400  7900072718      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
# 71998    400  7900072719      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
# 71999    400  7900072720      1  eBike E148  ...     US  New York  CLSAP18-F01   FERT
#
# [5 rows x 24 columns]

# %%
# MBRSH 값이 안들어가 있기 때문에 넣어주기

mbrsh = df01.loc[:,['MATNR','MBRSH']]
mbrsh = mbrsh.drop_duplicates()
display(mbrsh)
display(dfAdd.head())

dfAdd = pd.merge(dfAdd, mbrsh, on='MATNR')
display(dfAdd.head())

# 중복 컬럼 삭제
dfAdd = dfAdd.drop(['MBRSH_x'], axis=1)
display(dfAdd.head())

# 컬럼명 재설정
dfAdd = dfAdd.rename({'MBRSH_y': 'MBRSH'}, axis='columns')
display(dfAdd.head())
# Out:
#          MATNR MBRSH
# 0   CC-A08-F01     1
# 1   CC-A08-R01     1
# 2   CC-A08-R02     1
# 3   CC-A08-R03     1
# 4   CC-C07-F02     1
# ..         ...   ...
# 95    DS_RAW02     M
# 96    DUMMY-FG     M
# 97    DUMMY-RM     M
# 98        FG29     M
# 99   ML-CEMENT     M
#
# [100 rows x 2 columns]
#    MANDT       EBELN  EBELP  ... MTART MBRSH MBRSH
# 0    400  7900000721      1  ...   ROH     1     1
# 1    400  7900000722      1  ...   ROH     1     1
# 2    400  7900000723      1  ...   ROH     1     1
# 3    400  7900000724      1  ...   ROH     1     1
# 4    400  7900000725      1  ...   ROH     1     1
#
# [5 rows x 25 columns]
#    MANDT       EBELN  EBELP  ...  MBRSH_x  MBRSH_x MBRSH_y
# 0    400  7900000721      1  ...        1        1       1
# 1    400  7900000722      1  ...        1        1       1
# 2    400  7900000723      1  ...        1        1       1
# 3    400  7900000724      1  ...        1        1       1
# ...

# %%
# 중간용 xlsx 파일로 저장

midPoint = pd.DataFrame(dfAdd)
midPoint.to_excel(excel_writer='/content/drive/My Drive/SAP 5조 프로젝트/codefile/midPoint01.xlsx', header=True, index=False)

# %% [markdown]
# ### 5조_T002_구매계획정보테이블

# %%
# 새로 테이블 생성
# ['LIFNR', 'MATNR', 'MTART', 'MAKTX', 'NAME1', 'MBRSH', 'TPPRICE', 'TPAMOUNT', 'PDATE', 'PPRICE', 'MEINS', 'WAERS'] 컬럼 사용
# dfAdd 7200개의 구매 데이터 가져오기

cols = ['LIFNR', 'MATNR', 'MTART', 'MAKTX', 'NAME1', 'MBRSH','MEINS', 'WAERS']
dfAdd02 = dfAdd.loc[:,cols]
display(dfAdd02)  

# 필요한 새로운 컬럼 추가
# ['TPPRICE', 'TPAMOUNT', 'PDATE', 'PPRICE']

for co in ['TPPRICE', 'PAMOUNT', 'PDATE', 'PPRICE']:
    dfAdd02[co] = 'NA'
display(dfAdd02.head())
# Out:
#             LIFNR        MATNR MTART  ... MBRSH MEINS WAERS
# 0        10300080   CC-A08-R03   ROH  ...     1    EA   USD
# 1        10300080   CC-A08-R03   ROH  ...     1    EA   USD
# 2        10300080   CC-A08-R03   ROH  ...     1    EA   USD
# 3        10300080   CC-A08-R03   ROH  ...     1    EA   USD
# 4        10300080   CC-A08-R03   ROH  ...     1    EA   USD
# ...           ...          ...   ...  ...   ...   ...   ...
# 71995  9980000137  CLSAP18-F01  FERT  ...     A    EA   USD
# 71996  9980000137  CLSAP18-F01  FERT  ...     A    EA   USD
# 71997  9980000137  CLSAP18-F01  FERT  ...     A    EA   USD
# 71998  9980000137  CLSAP18-F01  FERT  ...     A    EA   USD
# 71999  9980000137  CLSAP18-F01  FERT  ...     A    EA   USD
#
# [72000 rows x 8 columns]
#       LIFNR       MATNR MTART  ... PAMOUNT PDATE PPRICE
# 0  10300080  CC-A08-R03   ROH  ...      NA    NA     NA
# 1  10300080  CC-A08-R03   ROH  ...      NA    NA     NA
# ...

# %%
# 구매계획수량 PAMOUNT: 납품예정수량을 기준으로 랜덤 값을 +/-


for _ in range(len(dfAdd02)):
    a = [0,0,0,0,0, random.randint(-100,10)]            #배열 속 0 갯수 또한 랜덤으로 들어가도록 설정해줘도 좋을 듯!!
    b = [0,0,0,0,0, random.randint(-200,200)]
    c = [0,0,0,0,0, random.randint(-10,10)]
    d = [0,0,0,0,0, random.randint(-20,20)]
    e = [0,0,0,0,0, random.randint(-60,60)]


    if dfAdd02['MATNR'][_] in [ matnr[0], matnr[1], matnr[2], matnr[3], matnr[4], matnr[5], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        dfAdd02['PAMOUNT'][_] =  dfAdd['MENGE'][_] + a[random.randint(0,5)]    
    elif dfAdd02['MATNR'][_] in [ matnr[10], matnr[11], matnr[12], matnr[13], matnr[14], matnr[15], 
                                     matnr[16], matnr[17], matnr[18], matnr[19]]:
        dfAdd02['PAMOUNT'][_] =  dfAdd['MENGE'][_] + a[random.randint(0,5)]     
    elif dfAdd02['MATNR'][_] in [ matnr[20], matnr[21], matnr[22], matnr[23], matnr[24], matnr[25], 
                                     matnr[26], matnr[27], matnr[28], matnr[29]]:
        dfAdd02['PAMOUNT'][_] =  dfAdd['MENGE'][_] + b[random.randint(0,5)]     
    elif dfAdd02['MATNR'][_] in [ matnr[30], matnr[31], matnr[32], matnr[33], matnr[34], matnr[35], 
                                     matnr[36], matnr[37], matnr[38], matnr[39]]:
        dfAdd02['PAMOUNT'][_] =  dfAdd['MENGE'][_] + b[random.randint(0,5)]    
    elif dfAdd02['MATNR'][_] in [ matnr[40], matnr[41], matnr[42], matnr[43], matnr[44], matnr[45], 
                                     matnr[46], matnr[47], matnr[48], matnr[49]]:
        dfAdd02['PAMOUNT'][_] =  dfAdd['MENGE'][_] + c[random.randint(0,5)]     
    elif dfAdd02['MATNR'][_] in [ matnr[50], matnr[51], matnr[52], matnr[53], matnr[54], matnr[55], 
                                     matnr[56], matnr[57], matnr[58], matnr[59]]:
        dfAdd02['PAMOUNT'][_] =  dfAdd['MENGE'][_] + c[random.randint(0,5)]     
    elif dfAdd02['MATNR'][_] in [ matnr[60], matnr[61], matnr[62], matnr[63], matnr[64], matnr[65], 
                                     matnr[66], matnr[67], matnr[68], matnr[69]]:
        dfAdd02['PAMOUNT'][_] =  dfAdd['MENGE'][_] + e[random.randint(0,5)]     
    elif dfAdd02['MATNR'][_] in [ matnr[70], matnr[71], matnr[72], matnr[73], matnr[74], matnr[75], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        dfAdd02['PAMOUNT'][_] =  dfAdd['MENGE'][_] + a[random.randint(0,5)]    
    elif dfAdd02['MATNR'][_] in [ matnr[80], matnr[81], matnr[82], matnr[83], matnr[84], matnr[85], 
                                     matnr[86], matnr[87], matnr[88], matnr[89]]:
        dfAdd02['PAMOUNT'][_] =  dfAdd['MENGE'][_] + e[random.randint(0,5)]     
    else:
        dfAdd02['PAMOUNT'][_] =  dfAdd['MENGE'][_] + c[random.randint(0,5)]

# %%
# 구매계획단가 PPRICE: 구매문서의 단가 NETPR 기준으로 랜덤 값을 +/-

for _ in range(len(dfAdd02)):
    a = [0,0,0,0,0, random.randint(-10,10)]
    b = [0,0,0,0,0, random.randint(-20,20)]
    c = [0,0,0,0,0, random.randint(-30,30)]
    d = [0,0,0,0,0, random.randint(-50,50)]
    e = [0,0,0,0,0, random.randint(-80,80)]
    
    if dfAdd02['MATNR'][_] in [ matnr[0], matnr[1], matnr[2], matnr[3], matnr[4], matnr[5], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        dfAdd02['PPRICE'][_] = dfAdd['NETPR'][_] + a[random.randint(0,5)]
    elif dfAdd02['MATNR'][_] in [ matnr[10], matnr[11], matnr[12], matnr[13], matnr[14], matnr[15], 
                                     matnr[16], matnr[17], matnr[18], matnr[19]]:
        dfAdd02['PPRICE'][_] = dfAdd['NETPR'][_] + a[random.randint(0,5)]
    elif dfAdd02['MATNR'][_] in [ matnr[20], matnr[21], matnr[22], matnr[23], matnr[24], matnr[25], 
                                     matnr[26], matnr[27], matnr[28], matnr[29]]:
        dfAdd02['PPRICE'][_] = dfAdd['NETPR'][_] + b[random.randint(0,5)]
    elif dfAdd02['MATNR'][_] in [ matnr[30], matnr[31], matnr[32], matnr[33], matnr[34], matnr[35], 
                                     matnr[36], matnr[37], matnr[38], matnr[39]]:
        dfAdd02['PPRICE'][_] = dfAdd['NETPR'][_] + c[random.randint(0,5)]
    elif dfAdd02['MATNR'][_] in [ matnr[40], matnr[41], matnr[42], matnr[43], matnr[44], matnr[45], 
                                     matnr[46], matnr[47], matnr[48], matnr[49]]:
        dfAdd02['PPRICE'][_] = dfAdd['NETPR'][_] + d[random.randint(0,5)]
    elif dfAdd02['MATNR'][_] in [ matnr[50], matnr[51], matnr[52], matnr[53], matnr[54], matnr[55], 
                                     matnr[56], matnr[57], matnr[58], matnr[59]]:
        dfAdd02['PPRICE'][_] = dfAdd['NETPR'][_] + a[random.randint(0,5)]
    elif dfAdd02['MATNR'][_] in [ matnr[60], matnr[61], matnr[62], matnr[63], matnr[64], matnr[65], 
                                     matnr[66], matnr[67], matnr[68], matnr[69]]:
        dfAdd02['PPRICE'][_] = dfAdd['NETPR'][_] + d[random.randint(0,5)]
    elif dfAdd02['MATNR'][_] in [ matnr[70], matnr[71], matnr[72], matnr[73], matnr[74], matnr[75], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        dfAdd02['PPRICE'][_] = dfAdd['NETPR'][_] + c[random.randint(0,5)]
    elif dfAdd02['MATNR'][_] in [ matnr[80], matnr[81], matnr[82], matnr[83], matnr[84], matnr[85], 
                                     matnr[86], matnr[87], matnr[88], matnr[89]]:
        dfAdd02['PPRICE'][_] = dfAdd['NETPR'][_] + e[random.randint(0,5)]
    else:
        dfAdd02['PPRICE'][_] = dfAdd['NETPR'][_] + c[random.randint(0,5)]

# %%
# 구매계획년월 PDATE :구매오더 생성일자 BEDAT 동일 값으로 넣음

for _ in range(len(dfAdd02)):
    dfAdd02['PDATE'][_] = dfAdd['BEDAT'][_]

# %%
# TPRICE = PAMOUNT * PPRICE 넣어주기

for _ in range(len(dfAdd02)):
    dfAdd02['TPPRICE'][_] = dfAdd02['PPRICE'][_] * dfAdd02['PAMOUNT'][_]

# %%
display(dfAdd02)
# Out:
#             LIFNR        MATNR MTART  ... PAMOUNT       PDATE PPRICE
# 0        10300080   CC-A08-R03   ROH  ...     966  2016-01-01    275
# 1        10300080   CC-A08-R03   ROH  ...    1047  2016-02-01    313
# 2        10300080   CC-A08-R03   ROH  ...     991  2016-03-01    318
# 3        10300080   CC-A08-R03   ROH  ...     960  2016-04-01    276
# 4        10300080   CC-A08-R03   ROH  ...     978  2016-05-01    342
# ...           ...          ...   ...  ...     ...         ...    ...
# 71995  9980000137  CLSAP18-F01  FERT  ...    4993  2018-08-01    492
# 71996  9980000137  CLSAP18-F01  FERT  ...    3964  2018-09-01    496
# 71997  9980000137  CLSAP18-F01  FERT  ...    4243  2018-10-01    509
# 71998  9980000137  CLSAP18-F01  FERT  ...    5523  2018-11-01    492
# 71999  9980000137  CLSAP18-F01  FERT  ...    4875  2018-12-01    495
#
# [72000 rows x 12 columns]

# %%
# 두번째 테이블 저장

midPoint2 = pd.DataFrame(dfAdd02)
midPoint2.to_excel(excel_writer='/content/drive/My Drive/SAP 5조 프로젝트/codefile/midPoint02.xlsx', header=True, index=False)

# %% [markdown]
# ### 5조_T003_외부시장단가테이블

# %%
# 새로 테이블 생성
# ['MATNR','MBRSH','MAKTX','MTART','AVPRICE','AVDATS','WAERS'] 컬럼 사용
# dfAdd 7200개의 구매 데이터 가져오기

cols = ['MATNR','MBRSH','MAKTX','MTART','WAERS','AEDAT']       #AEDAT 받아와서 'AVDATS'으로 컬럼명 바꿔 쓰기
dfAdd03 = dfAdd.loc[:,cols]
display(dfAdd03)  

# 필요한 새로운 컬럼 추가
dfAdd03['AVPRICE'] = 'NA'

# 컬럼명 변경
dfAdd03 = dfAdd03.rename({'AEDAT': 'AVDATS'}, axis='columns')
display(dfAdd03.head())
# Out:
#              MATNR MBRSH                        MAKTX MTART WAERS       AEDAT
# 0       CC-A08-R03     1  1ortable DVD Player PDP-121   ROH   USD  2016-01-01
# 1       CC-A08-R03     1  1ortable DVD Player PDP-121   ROH   USD  2016-02-01
# 2       CC-A08-R03     1  1ortable DVD Player PDP-121   ROH   USD  2016-03-01
# 3       CC-A08-R03     1  1ortable DVD Player PDP-121   ROH   USD  2016-04-01
# 4       CC-A08-R03     1  1ortable DVD Player PDP-121   ROH   USD  2016-05-01
# ...            ...   ...                          ...   ...   ...         ...
# 71995  CLSAP18-F01     A                   eBike E148  FERT   USD  2018-08-01
# 71996  CLSAP18-F01     A                   eBike E148  FERT   USD  2018-09-01
# 71997  CLSAP18-F01     A                   eBike E148  FERT   USD  2018-10-01
# 71998  CLSAP18-F01     A                   eBike E148  FERT   USD  2018-11-01
# 71999  CLSAP18-F01     A                   eBike E148  FERT   USD  2018-12-01
#
# [72000 rows x 6 columns]
# ...

# %%
# 시장평균단가 AVPRICE: 구매문서의 단가 NETPR 기준으로 랜덤 값을 +/-



for _ in range(len(dfAdd03)):
    
    a = [0,0,0,0,0, random.randint(-5,30)]
    b = [0,0,0,0,0, random.randint(-100,150)]
    c = [0,0,0,0,0, random.randint(-5,35)]
    d = [0,0,0,0,0, random.randint(-30,50)]
    e = [0,0,0,0,0, random.randint(-50,70)]
    
    if dfAdd03['MATNR'][_] in [ matnr[0], matnr[1], matnr[2], matnr[3], matnr[4], matnr[5], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        dfAdd03['AVPRICE'][_] = dfAdd['NETPR'][_] + a[random.randint(0,5)]
    elif dfAdd03['MATNR'][_] in [ matnr[10], matnr[11], matnr[12], matnr[13], matnr[14], matnr[15], 
                                     matnr[16], matnr[17], matnr[18], matnr[19]]:
        dfAdd03['AVPRICE'][_] = dfAdd['NETPR'][_] + a[random.randint(0,5)]
    elif dfAdd03['MATNR'][_] in [ matnr[20], matnr[21], matnr[22], matnr[23], matnr[24], matnr[25], 
                                     matnr[26], matnr[27], matnr[28], matnr[29]]:
        dfAdd03['AVPRICE'][_] = dfAdd['NETPR'][_] + b[random.randint(0,5)]
    elif dfAdd03['MATNR'][_] in [ matnr[30], matnr[31], matnr[32], matnr[33], matnr[34], matnr[35], 
                                     matnr[36], matnr[37], matnr[38], matnr[39]]:
        dfAdd03['AVPRICE'][_] = dfAdd['NETPR'][_] + c[random.randint(0,5)]
    elif dfAdd03['MATNR'][_] in [ matnr[40], matnr[41], matnr[42], matnr[43], matnr[44], matnr[45], 
                                     matnr[46], matnr[47], matnr[48], matnr[49]]:
        dfAdd03['AVPRICE'][_] = dfAdd['NETPR'][_] + b[random.randint(0,5)]
    elif dfAdd03['MATNR'][_] in [ matnr[50], matnr[51], matnr[52], matnr[53], matnr[54], matnr[55], 
                                     matnr[56], matnr[57], matnr[58], matnr[59]]:
        dfAdd03['AVPRICE'][_] = dfAdd['NETPR'][_] + a[random.randint(0,5)]
    elif dfAdd03['MATNR'][_] in [ matnr[60], matnr[61], matnr[62], matnr[63], matnr[64], matnr[65], 
                                     matnr[66], matnr[67], matnr[68], matnr[69]]:
        dfAdd03['AVPRICE'][_] = dfAdd['NETPR'][_] + d[random.randint(0,5)]
    elif dfAdd03['MATNR'][_] in [ matnr[70], matnr[71], matnr[72], matnr[73], matnr[74], matnr[75], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        dfAdd03['AVPRICE'][_] = dfAdd['NETPR'][_] + c[random.randint(0,5)]
    elif dfAdd03['MATNR'][_] in [ matnr[80], matnr[81], matnr[82], matnr[83], matnr[84], matnr[85], 
                                     matnr[86], matnr[87], matnr[88], matnr[89]]:
        dfAdd03['AVPRICE'][_] = dfAdd['NETPR'][_] + e[random.randint(0,5)]
    else:
        dfAdd03['AVPRICE'][_] = dfAdd['NETPR'][_] + c[random.randint(0,5)]

# %%
# 세번째 테이블 저장

midPoint3 = pd.DataFrame(dfAdd03)
midPoint3.to_excel(excel_writer='/content/drive/My Drive/SAP 5조 프로젝트/codefile/midPoint03.xlsx', header=True, index=False)

# %% [markdown]
# ### 날짜 타입 변경시 다음 코드 사용

# %%
# '전표증빙일 BLDAT'


# 납품요청일 데이터를 날짜 타입으로 변경
for _ in range(len(df01)):
    var1 = str(df01['납품요청일 EINDT'][_])
    var2 = datetime.datetime.strptime(var1, "%Y-%m-%d").date()
    df01['납품요청일 EINDT'][_] = var2 
    
    

# 납품요청일을 기준으로 랜덤 날짜를 더해 전표 증빙일 생성    
for _ in range(len(df01)):
    var3 = random.randint(0,6)                                  #날짜 적중률 보고 적절하게 변경하기 
    myList = [0,0,0,0,0,0, random.randint(-8,20)]               #날짜 적중률 보고 적절하게 변경하기 
    df01['전표증빙일 BLDAT'][_] = df01['납품요청일 EINDT'][_] + datetime.timedelta(days = myList[var3])

# %% [markdown]
# ### 날짜 - 제거시 다음 코드 사용

# %%
display(midPoint.head())
display(midPoint2.head())
display(midPoint3.head())


for _ in range(len(midPoint)):
    A = midPoint['EINDT'][_]
    B = midPoint['BLDAT'][_]
    C = midPoint['AEDAT'][_]
    D = midPoint['BEDAT'][_]
    
    midPoint['EINDT'][_] = A.replace("-","")
    midPoint['BLDAT'][_] = B.replace("-","")
    midPoint['AEDAT'][_] = C.replace("-","")
    midPoint['BEDAT'][_] = D.replace("-","")

for _ in range(len(midPoint2)):
    midPoint2['PDATE'][_] = midPoint2['PDATE'][_].replace("-","")    

for _ in range(len(midPoint3)):
    midPoint3['AVDATS'][_] = midPoint3['AVDATS'][_].replace("-","")
# Out:
#    MANDT       EBELN  EBELP  ...       MATNR  MTART MBRSH
# 0    400  7900000721      1  ...  CC-A08-R03    ROH     1
# 1    400  7900000722      1  ...  CC-A08-R03    ROH     1
# 2    400  7900000723      1  ...  CC-A08-R03    ROH     1
# 3    400  7900000724      1  ...  CC-A08-R03    ROH     1
# 4    400  7900000725      1  ...  CC-A08-R03    ROH     1
#
# [5 rows x 24 columns]
#       LIFNR       MATNR MTART  ... PAMOUNT       PDATE PPRICE
# 0  10300080  CC-A08-R03   ROH  ...     966  2016-01-01    275
# 1  10300080  CC-A08-R03   ROH  ...    1047  2016-02-01    313
# 2  10300080  CC-A08-R03   ROH  ...     991  2016-03-01    318
# 3  10300080  CC-A08-R03   ROH  ...     960  2016-04-01    276
# 4  10300080  CC-A08-R03   ROH  ...     978  2016-05-01    342
#
# [5 rows x 12 columns]
#         MATNR MBRSH                        MAKTX  ... WAERS      AVDATS AVPRICE
# 0  CC-A08-R03     1  1ortable DVD Player PDP-121  ...   USD  2016-01-01     275
# ...

# %%
display(midPoint.head())
display(midPoint2.head())
display(midPoint3.head())



midPoint.to_excel(excel_writer='/content/drive/My Drive/SAP 5조 프로젝트/codefile/midPoint01.xlsx', header=True, index=False)
midPoint2.to_excel(excel_writer='/content/drive/My Drive/SAP 5조 프로젝트/codefile/midPoint02.xlsx', header=True, index=False)
midPoint3.to_excel(excel_writer='/content/drive/My Drive/SAP 5조 프로젝트/codefile/midPoint03.xlsx', header=True, index=False)
# Out:
#    MANDT       EBELN  EBELP  ...       MATNR  MTART MBRSH
# 0    400  7900000721      1  ...  CC-A08-R03    ROH     1
# 1    400  7900000722      1  ...  CC-A08-R03    ROH     1
# 2    400  7900000723      1  ...  CC-A08-R03    ROH     1
# 3    400  7900000724      1  ...  CC-A08-R03    ROH     1
# 4    400  7900000725      1  ...  CC-A08-R03    ROH     1
#
# [5 rows x 24 columns]
#       LIFNR       MATNR MTART  ... PAMOUNT     PDATE PPRICE
# 0  10300080  CC-A08-R03   ROH  ...     966  20160101    275
# 1  10300080  CC-A08-R03   ROH  ...    1047  20160201    313
# 2  10300080  CC-A08-R03   ROH  ...     991  20160301    318
# 3  10300080  CC-A08-R03   ROH  ...     960  20160401    276
# 4  10300080  CC-A08-R03   ROH  ...     978  20160501    342
#
# [5 rows x 12 columns]
#         MATNR MBRSH                        MAKTX MTART WAERS    AVDATS AVPRICE
# 0  CC-A08-R03     1  1ortable DVD Player PDP-121   ROH   USD  20160101     275
# ...
