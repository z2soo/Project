# %% [markdown]
# ### 필요 모듈 import

# %%
# 필요한 module import

import random
import pandas as pd
import warnings
import datetime
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### 파일 불러오기 및 데이터 구조 확인

# %%
# 제대로 파일이 읽혔는지 확인

df01 = pd.read_csv("5조_T001_구매정보테이블.csv")
display(df01.head())

df02 = pd.read_csv("5조_T002_구매계획정보테이블.csv")
display(df02.head())

df03 = pd.read_csv("5조_T003_외부시장단가테이블.csv")
display(df03.head())
# Out:
#    클라이언트명 MANDT   구매문서번호 EBELN  자재번호 MATNR  구매오더품목번호 EBELP  \
# 0            400    7900000001  CC-A08-F01               1
# 1            400    7900000001  CC-A08-R01               2
# 2            400    7900000001  CC-A08-R02               3
# 3            400    7900000001  CC-A08-R03               4
# 4            400    7900000001  CC-C07-F02               5
#
#                      자재명 MAKTX 자재유형명 MTART  플랜트 WERKS 수량단위 MEINS  \
# 0              Cross Racer 3.0         ROH       1710         EA
# 1                   Bike Paint         ROH       1710         EA
# 2          USB Adapter USB-901         ROH       1710         EA
# 3  1ortable DVD Player PDP-121         ROH       1710         EA
# 4                    Headlight         ROH       1710         EA
#
#    구매문서의 단가 NETPR  총구매금액 BRTWR  ...   공급업체 전화번호 TELF1  구매오더 생성일자 BEDAT  \
# 0             NaN          0.0  ...  (86216) 227-0403       2016-01-01
# 1             NaN          0.0  ...  (86216) 227-0403       2016-01-01
# ...

# %%
# 데이터 수 확인

print(len(df01))
print(len(df02))
print(len(df03))
# Out:
# 3600
# 3600
# 3600

# %%
# column명이랑 자재명 확인

cols01 = df01.columns
cols02 = df02.columns
cols03 = df03.columns
print(cols01)
print(cols02)
print(cols03)

matnr01 = df01['자재번호 MATNR'].unique()
#matnr01 = list(matnr01)
print(len(matnr01))                                  #table01 자재갯수가 100개 맞는지 확인: 맞음

matnr02 = df02['자재번호 MATNR'].unique()
#matnr02 = list(matnr02)
print(len(matnr02))                                  #table02 자재갯수가 100개 맞는지 확인: 맞음

matnr03 = df01['자재번호 MATNR'].unique()
#matnr03 = list(matnr03)
print(len(matnr03))                                  #table03 자재갯수가 100개 맞는지 확인: 맞음

# table02 컬럼명 변경: '총구매계획수량 TPAMOUNT' -> '구매계획수량 PAMOUNT'
df02.rename(columns={'총구매계획수량 TPAMOUNT':'구매계획수량 PAMOUNT'}, inplace=True)
print(df02.columns)                                  #변경완료
# Out:
# Index(['클라이언트명 MANDT ', '구매문서번호 EBELN', '자재번호 MATNR', '구매오더품목번호 EBELP',
#        '자재명 MAKTX', '자재유형명 MTART', '플랜트 WERKS', '수량단위 MEINS', '구매문서의 단가 NETPR',
#        '총구매금액 BRTWR', '구매오더 변경일자 AEDAT', '반품 품목 RETPO', '공급업체번호 LIFNR',
#        '구매조직 EKORG', '통화 WAERS', '공급업체 전화번호 TELF1', '구매오더 생성일자 BEDAT',
#        '납품입고수량 WEMNG', '납품예정수량 MENGE', '공급업체명 NAME1', '공급업체주소 LAND1',
#        '공급업체주소 ORT01', '납품요청일 EINDT', '전표증빙일 BLDAT', '산업부문 MBRSH'],
#       dtype='object')
# Index(['공급업체번호 LIFNR', '자재번호 MATNR', '자재유형명 MTART', '자재명 MAKTX',
#        '공급업체이름 NAME1', '산업부문 MBRSH', '총구매계획금액 TPPRICE', '총구매계획수량 TPAMOUNT',
#        '구매계획년월 PDATE', '구매계획단가 PPRICE', '수량단위(구매오더단위) MEINS', '통화 WAERS'],
#       dtype='object')
# Index(['자재번호 MATNR', '산업부문 MBRSH', '자재명 MAKTX', '자재유형명 MTART',
#        '시장평균단가 AVPRICE', '시장평균단가 생성년월 AVDATS', '통화 WAERS'],
#       dtype='object')
# 100
# 100
# 100
# Index(['공급업체번호 LIFNR', '자재번호 MATNR', '자재유형명 MTART', '자재명 MAKTX',
# ...

# %% [markdown]
# ### 5조_T001_구매정보테이블

# %%
# 구매문서의 단가 NETPR

for _ in range(len(df01)):
    a = random.randint(-70,70)
    b = random.randint(-10,10)
    c = random.randint(-30,30)
    d = random.randint(-100,100)
    e = random.randint(-150,150)
    
    if df01['자재번호 MATNR'][_] in [ matnr[0], matnr[1], matnr[2], matnr[3], matnr[4], matnr[5], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        df01['구매문서의 단가 NETPR'][_] = 300 + a
    elif df01['자재번호 MATNR'][_] in [ matnr[10], matnr[11], matnr[12], matnr[13], matnr[14], matnr[15], 
                                     matnr[16], matnr[17], matnr[18], matnr[19]]:
        df01['구매문서의 단가 NETPR'][_] = 300 + a
    elif df01['자재번호 MATNR'][_] in [ matnr[20], matnr[21], matnr[22], matnr[23], matnr[24], matnr[25], 
                                     matnr[26], matnr[27], matnr[28], matnr[29]]:
        df01['구매문서의 단가 NETPR'][_] = 500 + b
    elif df01['자재번호 MATNR'][_] in [ matnr[30], matnr[31], matnr[32], matnr[33], matnr[34], matnr[35], 
                                     matnr[36], matnr[37], matnr[38], matnr[39]]:
        df01['구매문서의 단가 NETPR'][_] = 800 + c
    elif df01['자재번호 MATNR'][_] in [ matnr[40], matnr[41], matnr[42], matnr[43], matnr[44], matnr[45], 
                                     matnr[46], matnr[47], matnr[48], matnr[49]]:
        df01['구매문서의 단가 NETPR'][_] = 1000 + d
    elif df01['자재번호 MATNR'][_] in [ matnr[50], matnr[51], matnr[52], matnr[53], matnr[54], matnr[55], 
                                     matnr[56], matnr[57], matnr[58], matnr[59]]:
        df01['구매문서의 단가 NETPR'][_] = 750 + a
    elif df01['자재번호 MATNR'][_] in [ matnr[60], matnr[61], matnr[62], matnr[63], matnr[64], matnr[65], 
                                     matnr[66], matnr[67], matnr[68], matnr[69]]:
        df01['구매문서의 단가 NETPR'][_] = 900 + d
    elif df01['자재번호 MATNR'][_] in [ matnr[70], matnr[71], matnr[72], matnr[73], matnr[74], matnr[75], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        df01['구매문서의 단가 NETPR'][_] = 950 + c
    elif df01['자재번호 MATNR'][_] in [ matnr[80], matnr[81], matnr[82], matnr[83], matnr[84], matnr[85], 
                                     matnr[86], matnr[87], matnr[88], matnr[89]]:
        df01['구매문서의 단가 NETPR'][_] = 1500 + e
    else:
        df01['구매문서의 단가 NETPR'][_] = 450 + c

# %%
# 납품예정수량 MENGE

for _ in range(len(df01)):
    a = random.randint(-1000,1000)
    b = random.randint(0,5000)
    c = random.randint(-50,50)
    d = random.randint(0,1000)
    e = random.randint(-100,100)
    f = random.randint(-500, 500)
    
    if df01['자재번호 MATNR'][_] in [ matnr[0], matnr[1], matnr[2], matnr[3], matnr[4], matnr[5], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        df01['납품예정수량 MENGE'][_] = 1000 + c
    elif df01['자재번호 MATNR'][_] in [ matnr[10], matnr[11], matnr[12], matnr[13], matnr[14], matnr[15], 
                                     matnr[16], matnr[17], matnr[18], matnr[19]]:
        df01['납품예정수량 MENGE'][_] = 3000 + f
    elif df01['자재번호 MATNR'][_] in [ matnr[20], matnr[21], matnr[22], matnr[23], matnr[24], matnr[25], 
                                     matnr[26], matnr[27], matnr[28], matnr[29]]:
        df01['납품예정수량 MENGE'][_] = 5000 + a
    elif df01['자재번호 MATNR'][_] in [ matnr[30], matnr[31], matnr[32], matnr[33], matnr[34], matnr[35], 
                                     matnr[36], matnr[37], matnr[38], matnr[39]]:
        df01['납품예정수량 MENGE'][_] = 8000 + a
    elif df01['자재번호 MATNR'][_] in [ matnr[40], matnr[41], matnr[42], matnr[43], matnr[44], matnr[45], 
                                     matnr[46], matnr[47], matnr[48], matnr[49]]:
        df01['납품예정수량 MENGE'][_] = 1000 + f
    elif df01['자재번호 MATNR'][_] in [ matnr[50], matnr[51], matnr[52], matnr[53], matnr[54], matnr[55], 
                                     matnr[56], matnr[57], matnr[58], matnr[59]]:
        df01['납품예정수량 MENGE'][_] = 750 + c
    elif df01['자재번호 MATNR'][_] in [ matnr[60], matnr[61], matnr[62], matnr[63], matnr[64], matnr[65], 
                                     matnr[66], matnr[67], matnr[68], matnr[69]]:
        df01['납품예정수량 MENGE'][_] = 3000 + b
    elif df01['자재번호 MATNR'][_] in [ matnr[70], matnr[71], matnr[72], matnr[73], matnr[74], matnr[75], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        df01['납품예정수량 MENGE'][_] = 1500 + f
    elif df01['자재번호 MATNR'][_] in [ matnr[80], matnr[81], matnr[82], matnr[83], matnr[84], matnr[85], 
                                     matnr[86], matnr[87], matnr[88], matnr[89]]:
        df01['납품예정수량 MENGE'][_] = 1500 + d
    else:
        df01['납품예정수량 MENGE'][_] = 450 + c

# %%
# 납품입고수량 WEMNG: 예정 수량을 기준으로 랜덤 값을 빼줌

for _ in range(len(df01)):
    #a = random.randint(-500,0)
    #b = random.randint(-1000,0)
    #c = random.randint(-50,0)
    #d = random.randint(-100,0)
    #e = random.randint(-300,0) 
    a = [0,0,0,0,0, random.randint(-500,0)]               #배열 속 0 갯수 또한 랜덤으로 들어가도록 설정해줘도 좋을 듯!!
    b = [0,0,0,0,0, random.randint(-1000,0)]
    c = [0,0,0,0,0, random.randint(-50,0)]
    d = [0,0,0,0,0, random.randint(-100,0)] 
    e = [0,0,0,0,0, random.randint(-300,0)]
    

    if df01['자재번호 MATNR'][_] in [ matnr[0], matnr[1], matnr[2], matnr[3], matnr[4], matnr[5], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        df01['납품입고수량 WEMNG'][_] =  df01['납품예정수량 MENGE'][_] + a[random.randint(0,5)]    
    elif df01['자재번호 MATNR'][_] in [ matnr[10], matnr[11], matnr[12], matnr[13], matnr[14], matnr[15], 
                                     matnr[16], matnr[17], matnr[18], matnr[19]]:
        df01['납품입고수량 WEMNG'][_] =  df01['납품예정수량 MENGE'][_] + a[random.randint(0,5)]     
    elif df01['자재번호 MATNR'][_] in [ matnr[20], matnr[21], matnr[22], matnr[23], matnr[24], matnr[25], 
                                     matnr[26], matnr[27], matnr[28], matnr[29]]:
        df01['납품입고수량 WEMNG'][_] =  df01['납품예정수량 MENGE'][_] + b[random.randint(0,5)]     
    elif df01['자재번호 MATNR'][_] in [ matnr[30], matnr[31], matnr[32], matnr[33], matnr[34], matnr[35], 
                                     matnr[36], matnr[37], matnr[38], matnr[39]]:
        df01['납품입고수량 WEMNG'][_] =  df01['납품예정수량 MENGE'][_] + b[random.randint(0,5)]    
    elif df01['자재번호 MATNR'][_] in [ matnr[40], matnr[41], matnr[42], matnr[43], matnr[44], matnr[45], 
                                     matnr[46], matnr[47], matnr[48], matnr[49]]:
        df01['납품입고수량 WEMNG'][_] =  df01['납품예정수량 MENGE'][_] + c[random.randint(0,5)]     
    elif df01['자재번호 MATNR'][_] in [ matnr[50], matnr[51], matnr[52], matnr[53], matnr[54], matnr[55], 
                                     matnr[56], matnr[57], matnr[58], matnr[59]]:
        df01['납품입고수량 WEMNG'][_] =  df01['납품예정수량 MENGE'][_] + c[random.randint(0,5)]     
    elif df01['자재번호 MATNR'][_] in [ matnr[60], matnr[61], matnr[62], matnr[63], matnr[64], matnr[65], 
                                     matnr[66], matnr[67], matnr[68], matnr[69]]:
        df01['납품입고수량 WEMNG'][_] =  df01['납품예정수량 MENGE'][_] + e[random.randint(0,5)]    
    elif df01['자재번호 MATNR'][_] in [ matnr[70], matnr[71], matnr[72], matnr[73], matnr[74], matnr[75], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        df01['납품입고수량 WEMNG'][_] =  df01['납품예정수량 MENGE'][_] + a[random.randint(0,5)]     
    elif df01['자재번호 MATNR'][_] in [ matnr[80], matnr[81], matnr[82], matnr[83], matnr[84], matnr[85], 
                                     matnr[86], matnr[87], matnr[88], matnr[89]]:
        df01['납품입고수량 WEMNG'][_] =  df01['납품예정수량 MENGE'][_] + e[random.randint(0,5)]     
    else:
        df01['납품입고수량 WEMNG'][_] =  df01['납품예정수량 MENGE'][_] + c[random.randint(0,5)]

# %%
# 총구매금액 BRTWR: 구매문서의 단가 NETPR * 납품예정수량 MENGE

for _ in range(len(df02)):
    df01['총구매금액 BRTWR'][_] = df01['구매문서의 단가 NETPR'][_] * df01['납품예정수량 MENGE'][_]

# %% [markdown]
# ### 5조_T002_구매계획정보테이블

# %%
# 구매계획수량 PAMOUNT: 납품예정수량을 기준으로 랜덤 값을 +/-


for _ in range(len(df02)):
    a = [0,0,0,0,0, random.randint(-100,10)]            #배열 속 0 갯수 또한 랜덤으로 들어가도록 설정해줘도 좋을 듯!!
    b = [0,0,0,0,0, random.randint(-200,200)]
    c = [0,0,0,0,0, random.randint(-10,10)]
    d = [0,0,0,0,0, random.randint(-20,20)]
    e = [0,0,0,0,0, random.randint(-60,60)]


    if df02['자재번호 MATNR'][_] in [ matnr[0], matnr[1], matnr[2], matnr[3], matnr[4], matnr[5], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        df02['구매계획수량 PAMOUNT'][_] =  df01['납품예정수량 MENGE'][_] + a[random.randint(0,5)]    
    elif df02['자재번호 MATNR'][_] in [ matnr[10], matnr[11], matnr[12], matnr[13], matnr[14], matnr[15], 
                                     matnr[16], matnr[17], matnr[18], matnr[19]]:
        df02['구매계획수량 PAMOUNT'][_] =  df01['납품예정수량 MENGE'][_] + a[random.randint(0,5)]     
    elif df02['자재번호 MATNR'][_] in [ matnr[20], matnr[21], matnr[22], matnr[23], matnr[24], matnr[25], 
                                     matnr[26], matnr[27], matnr[28], matnr[29]]:
        df02['구매계획수량 PAMOUNT'][_] =  df01['납품예정수량 MENGE'][_] + b[random.randint(0,5)]     
    elif df02['자재번호 MATNR'][_] in [ matnr[30], matnr[31], matnr[32], matnr[33], matnr[34], matnr[35], 
                                     matnr[36], matnr[37], matnr[38], matnr[39]]:
        df02['구매계획수량 PAMOUNT'][_] =  df01['납품예정수량 MENGE'][_] + b[random.randint(0,5)]    
    elif df02['자재번호 MATNR'][_] in [ matnr[40], matnr[41], matnr[42], matnr[43], matnr[44], matnr[45], 
                                     matnr[46], matnr[47], matnr[48], matnr[49]]:
        df02['구매계획수량 PAMOUNT'][_] =  df01['납품예정수량 MENGE'][_] + c[random.randint(0,5)]     
    elif df02['자재번호 MATNR'][_] in [ matnr[50], matnr[51], matnr[52], matnr[53], matnr[54], matnr[55], 
                                     matnr[56], matnr[57], matnr[58], matnr[59]]:
        df02['구매계획수량 PAMOUNT'][_] =  df01['납품예정수량 MENGE'][_] + c[random.randint(0,5)]     
    elif df02['자재번호 MATNR'][_] in [ matnr[60], matnr[61], matnr[62], matnr[63], matnr[64], matnr[65], 
                                     matnr[66], matnr[67], matnr[68], matnr[69]]:
        df02['구매계획수량 PAMOUNT'][_] =  df01['납품예정수량 MENGE'][_] + e[random.randint(0,5)]     
    elif df02['자재번호 MATNR'][_] in [ matnr[70], matnr[71], matnr[72], matnr[73], matnr[74], matnr[75], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        df02['구매계획수량 PAMOUNT'][_] =  df01['납품예정수량 MENGE'][_] + a[random.randint(0,5)]    
    elif df02['자재번호 MATNR'][_] in [ matnr[80], matnr[81], matnr[82], matnr[83], matnr[84], matnr[85], 
                                     matnr[86], matnr[87], matnr[88], matnr[89]]:
        df02['구매계획수량 PAMOUNT'][_] =  df01['납품예정수량 MENGE'][_] + e[random.randint(0,5)]     
    else:
        df02['구매계획수량 PAMOUNT'][_] =  df01['납품예정수량 MENGE'][_] + c[random.randint(0,5)]

# %%
# 구매계획단가 PPRICE: 구매문서의 단가 NETPR 기준으로 랜덤 값을 +/-

for _ in range(len(df02)):
    a = [0,0,0,0,0, random.randint(-10,10)]
    b = [0,0,0,0,0, random.randint(-20,20)]
    c = [0,0,0,0,0, random.randint(-30,30)]
    d = [0,0,0,0,0, random.randint(-50,50)]
    e = [0,0,0,0,0, random.randint(-80,80)]
    
    if df02['자재번호 MATNR'][_] in [ matnr[0], matnr[1], matnr[2], matnr[3], matnr[4], matnr[5], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        df02['구매계획단가 PPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + a[random.randint(0,5)]
    elif df02['자재번호 MATNR'][_] in [ matnr[10], matnr[11], matnr[12], matnr[13], matnr[14], matnr[15], 
                                     matnr[16], matnr[17], matnr[18], matnr[19]]:
        df02['구매계획단가 PPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + a[random.randint(0,5)]
    elif df02['자재번호 MATNR'][_] in [ matnr[20], matnr[21], matnr[22], matnr[23], matnr[24], matnr[25], 
                                     matnr[26], matnr[27], matnr[28], matnr[29]]:
        df02['구매계획단가 PPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + b[random.randint(0,5)]
    elif df02['자재번호 MATNR'][_] in [ matnr[30], matnr[31], matnr[32], matnr[33], matnr[34], matnr[35], 
                                     matnr[36], matnr[37], matnr[38], matnr[39]]:
        df02['구매계획단가 PPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + c[random.randint(0,5)]
    elif df02['자재번호 MATNR'][_] in [ matnr[40], matnr[41], matnr[42], matnr[43], matnr[44], matnr[45], 
                                     matnr[46], matnr[47], matnr[48], matnr[49]]:
        df02['구매계획단가 PPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + d[random.randint(0,5)]
    elif df02['자재번호 MATNR'][_] in [ matnr[50], matnr[51], matnr[52], matnr[53], matnr[54], matnr[55], 
                                     matnr[56], matnr[57], matnr[58], matnr[59]]:
        df02['구매계획단가 PPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + a[random.randint(0,5)]
    elif df02['자재번호 MATNR'][_] in [ matnr[60], matnr[61], matnr[62], matnr[63], matnr[64], matnr[65], 
                                     matnr[66], matnr[67], matnr[68], matnr[69]]:
        df02['구매계획단가 PPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + d[random.randint(0,5)]
    elif df02['자재번호 MATNR'][_] in [ matnr[70], matnr[71], matnr[72], matnr[73], matnr[74], matnr[75], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        df02['구매계획단가 PPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + c[random.randint(0,5)]
    elif df02['자재번호 MATNR'][_] in [ matnr[80], matnr[81], matnr[82], matnr[83], matnr[84], matnr[85], 
                                     matnr[86], matnr[87], matnr[88], matnr[89]]:
        df02['구매계획단가 PPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + e[random.randint(0,5)]
    else:
        df02['구매계획단가 PPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + c[random.randint(0,5)]

# %%
# 구매계획년월 PDATE :구매오더 생성일자 BEDAT 동일 값으로 넣음

for _ in range(len(df02)):
    df02['구매계획년월 PDATE'][_] = df01['구매오더 생성일자 BEDAT'][_]

# %% [markdown]
# ### 5조_T003_외부시장단가테이블

# %%
# 시장평균단가 AVPRICE: 구매문서의 단가 NETPR 기준으로 랜덤 값을 +/-


for _ in range(len(df03)):
    
    a = [0,0,0,0,0, random.randint(-5,5)]
    b = [0,0,0,0,0, random.randint(-10,10)]
    c = [0,0,0,0,0, random.randint(-15,15)]
    d = [0,0,0,0,0, random.randint(-30,30)]
    e = [0,0,0,0,0, random.randint(-50,50)]
    
    if df03['자재번호 MATNR'][_] in [ matnr[0], matnr[1], matnr[2], matnr[3], matnr[4], matnr[5], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        df03['시장평균단가 AVPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + a[random.randint(0,5)]
    elif df03['자재번호 MATNR'][_] in [ matnr[10], matnr[11], matnr[12], matnr[13], matnr[14], matnr[15], 
                                     matnr[16], matnr[17], matnr[18], matnr[19]]:
        df03['시장평균단가 AVPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + a[random.randint(0,5)]
    elif df03['자재번호 MATNR'][_] in [ matnr[20], matnr[21], matnr[22], matnr[23], matnr[24], matnr[25], 
                                     matnr[26], matnr[27], matnr[28], matnr[29]]:
        df03['시장평균단가 AVPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + b[random.randint(0,5)]
    elif df03['자재번호 MATNR'][_] in [ matnr[30], matnr[31], matnr[32], matnr[33], matnr[34], matnr[35], 
                                     matnr[36], matnr[37], matnr[38], matnr[39]]:
        df03['시장평균단가 AVPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + c[random.randint(0,5)]
    elif df03['자재번호 MATNR'][_] in [ matnr[40], matnr[41], matnr[42], matnr[43], matnr[44], matnr[45], 
                                     matnr[46], matnr[47], matnr[48], matnr[49]]:
        df03['시장평균단가 AVPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + d[random.randint(0,5)]
    elif df03['자재번호 MATNR'][_] in [ matnr[50], matnr[51], matnr[52], matnr[53], matnr[54], matnr[55], 
                                     matnr[56], matnr[57], matnr[58], matnr[59]]:
        df03['시장평균단가 AVPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + a[random.randint(0,5)]
    elif df03['자재번호 MATNR'][_] in [ matnr[60], matnr[61], matnr[62], matnr[63], matnr[64], matnr[65], 
                                     matnr[66], matnr[67], matnr[68], matnr[69]]:
        df03['시장평균단가 AVPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + d[random.randint(0,5)]
    elif df03['자재번호 MATNR'][_] in [ matnr[70], matnr[71], matnr[72], matnr[73], matnr[74], matnr[75], 
                                     matnr[6], matnr[7], matnr[8], matnr[9]]:
        df03['시장평균단가 AVPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + c[random.randint(0,5)]
    elif df03['자재번호 MATNR'][_] in [ matnr[80], matnr[81], matnr[82], matnr[83], matnr[84], matnr[85], 
                                     matnr[86], matnr[87], matnr[88], matnr[89]]:
        df03['시장평균단가 AVPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + e[random.randint(0,5)]
    else:
        df03['시장평균단가 AVPRICE'][_] = df01['구매문서의 단가 NETPR'][_] + c[random.randint(0,5)]

# %%
# '전표증빙일 BLDAT'


# 납품요청일 데이터를 날짜 타입으로 변경
for _ in range(len(df01)):
    var1 = str(df01['납품요청일 EINDT'][_])
    var2 = datetime.datetime.strptime(var1, "%Y-%m-%d").date()
    df01['납품요청일 EINDT'][_] = var2 
    
    

# 납품요청일을 기준으로 랜덤 날짜를 더해 전표 증빙일 생성    
for _ in range(len(df01)):
    var3 = random.randint(0,6)                                  #날짜 적중률 보고 적절하게 변경하기 
    myList = [0,0,0,0,0,0, random.randint(-8,20)]               #날짜 적중률 보고 적절하게 변경하기 
    df01['전표증빙일 BLDAT'][_] = df01['납품요청일 EINDT'][_] + datetime.timedelta(days = myList[var3])

# %%
display(df01.head())
display(df02.head())
display(df03.head())
# Out:
#    클라이언트명 MANDT   구매문서번호 EBELN  자재번호 MATNR  구매오더품목번호 EBELP  \
# 0            400    7900000001  CC-A08-F01               1
# 1            400    7900000001  CC-A08-R01               2
# 2            400    7900000001  CC-A08-R02               3
# 3            400    7900000001  CC-A08-R03               4
# 4            400    7900000001  CC-C07-F02               5
#
#                      자재명 MAKTX 자재유형명 MTART  플랜트 WERKS 수량단위 MEINS  \
# 0              Cross Racer 3.0         ROH       1710         EA
# 1                   Bike Paint         ROH       1710         EA
# 2          USB Adapter USB-901         ROH       1710         EA
# 3  1ortable DVD Player PDP-121         ROH       1710         EA
# 4                    Headlight         ROH       1710         EA
#
#    구매문서의 단가 NETPR  총구매금액 BRTWR  ...   공급업체 전화번호 TELF1  구매오더 생성일자 BEDAT  \
# 0           299.0     297505.0  ...  (86216) 227-0403       2016-01-01
# 1           329.0     332948.0  ...  (86216) 227-0403       2016-01-01
# ...

# %% [markdown]
# ### 파일로 저장

# %%
# 컬럼명 변경

df01.columns = ['MANDT','EBELN','MATNR','EBELP','MAKTX','MTART','WERKS','MEINS','NETPR',
                'BRTWR','AEDAT','RETPO','LIFNR','EKORG','WAERS','TELF1','BEDAT',
                'WEMNG','MENGE','NAME1','LAND1','ORT01','EINDT','BLDAT','MBRSH']
df02.columns = ['LIFNR','MATNR','MTART','MAKTX','NAME1','MBRSH','TPPRICE', 
                'TPAMOUNT','PDATE','PPRICE','MEINS','WAERS']
df03.columns = ['MATNR','MBRSH','MAKTX','MTART','AVPRICE','AVDATS','WAERS']

# %%
result01 = pd.DataFrame(df01)
result02 = pd.DataFrame(df02)
result03 = pd.DataFrame(df03)

# xlsx 파일로 저장
result01.to_excel(excel_writer='ZC05MMT001.xlsx', header=True, index=False)
result02.to_excel(excel_writer='ZC05MMT002.xlsx', header=True, index=False)
result03.to_excel(excel_writer='ZC05MMT003.xlsx', header=True, index=False)

# csv 파일로 저장
# result01.to_csv('ZC05MMT001.csv', header=True, index=False) 
# result02.to_csv('ZC05MMT002.csv', header=True, index=False) 
# result03.to_csv('ZC05MMT003.csv', header=True, index=False)
